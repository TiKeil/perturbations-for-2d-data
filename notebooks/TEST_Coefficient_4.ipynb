# %% [markdown]
# # VCLOD Test for Coefficient 4
#
# This script performs the main VCLOD test for this thesis with a specific diffusion coefficient. We investigate the energy error of the VCLOD dependent on the updated correctors. For this purpose, we update every corrector individually and compare it to the reference solution. This enables a good comparison between percentages. We desire to yield a fast decrease of the energy error of the VCLOD method since, due to the error indicator, we sort and update the element correctors in terms of the effect that comes with the perturbation.

# %%
import os
import sys
import numpy as np
import scipy.sparse as sparse
import random
import csv

# %matplotlib notebook
import matplotlib.pyplot as plt
from visualize import drawCoefficient
from data import * 

from gridlod import interp, coef, util, fem, world, linalg, femsolver
import pg_rand, femsolverCoarse, buildcoef2d
from gridlod.world import World

# %% [markdown]
# ## Result function
#
# The 'result' function investigates the VCLOD for each percentage. The reference solution is computed by a standard FEM on the fine mesh. We compute the 'worst solution' that represents zero percentage updating and clearly has no computational cost at all. Afterwards, we compute the error indicator for the given patch size $k=4$ and use every value gradually. Furthermore we store the resulting energy error for the VCLOD as well as the optimal energy error that results from 100 percentage updating. Once again, we take advantage of the 'gridlod' module in order to compute the required matrices.

# %%
def result(pglod, world, A, R, f, k, String):
    print "-------------- " + String + " ---------------" 
    NWorldFine = world.NWorldFine
    NWorldCoarse = world.NWorldCoarse
    NCoarseElement = world.NCoarseElement
    
    boundaryConditions = world.boundaryConditions
    NpFine = np.prod(NWorldFine+1)
    NpCoarse = np.prod(NWorldCoarse+1)
        
    # new Coefficient
    ANew = R.flatten()
    Anew = coef.coefficientFine(NWorldCoarse, NCoarseElement, ANew)
    
    # reference solution
    f_fine = np.ones(NpFine)
    uFineFem, AFine, MFine = femsolver.solveFine(world, ANew, f_fine, None, boundaryConditions)
    
    # worst solution
    KFull = pglod.assembleMsStiffnessMatrix()
    MFull = fem.assemblePatchMatrix(NWorldCoarse, world.MLocCoarse)
    free  = util.interiorpIndexMap(NWorldCoarse)                                 
    
    bFull = MFull*f
    KFree = KFull[free][:,free]
    bFree = bFull[free]

    xFree = sparse.linalg.spsolve(KFree, bFree)
    
    basis = fem.assembleProlongationMatrix(NWorldCoarse, NCoarseElement)
    
    basisCorrectors = pglod.assembleBasisCorrectors()
    modifiedBasis = basis - basisCorrectors
    
    xFull = np.zeros(NpCoarse)
    xFull[free] = xFree
    uCoarse = xFull
    uLodFine = modifiedBasis*xFull
    
    uLodFineWorst = uLodFine
    
    # energy error
    errorworst = np.sqrt(np.dot(uFineFem - uLodFineWorst, AFine*(uFineFem - uLodFineWorst)))
    
    # tolerance = 0 
    vis, eps = pglod.updateCorrectors(Anew, 0, f, 1, clearFineQuantities=False, Computing=False)
    
    PotentialCorrectors = np.sum(vis)
    elemente = np.arange(np.prod(NWorldCoarse))
            
    # identify tolerances
    epsnozero = filter(lambda x: x!=0, eps)
    
    assert(np.size(epsnozero) != 0)
    
    mini = np.min(epsnozero)
    minilog = int(round(np.log10(mini)-0.49))
    epsnozero.append(10**(minilog))
    ToleranceListcomplete = []
    for i in range(0,int(np.size(epsnozero))):
        ToleranceListcomplete.append(epsnozero[i])

    ToleranceListcomplete.sort()
    ToleranceListcomplete = np.unique(ToleranceListcomplete)

    # with tolerance
    errorplotinfo = []
    tolerancesafe = []
    errorBest = []
    errorWorst = []
    recomputefractionsafe = []
    recomputefraction = 0
    Correctors = 0
    leng = np.size(ToleranceListcomplete)
    for k in range(leng-1,-1,-1):
        tol = ToleranceListcomplete[k]
        print " --- "+ str(-k+leng) + "/" + str(leng)+ " --- Tolerance: " + str(round(tol,5)) + " in "+ String +" ---- ", 
        vistol = pglod.updateCorrectors(Anew, tol, f, clearFineQuantities=False, Testing=True)
        
        Correctors += np.sum(vistol)
        
        recomputefraction += float(np.sum(vistol))/PotentialCorrectors * 100
        recomputefractionsafe.append(recomputefraction)
        
        KFull = pglod.assembleMsStiffnessMatrix()
        MFull = fem.assemblePatchMatrix(NWorldCoarse, world.MLocCoarse)
        free  = util.interiorpIndexMap(NWorldCoarse)                                 

        bFull = MFull*f
        KFree = KFull[free][:,free]
        bFree = bFull[free]

        xFree = sparse.linalg.spsolve(KFree, bFree)
        basis = fem.assembleProlongationMatrix(NWorldCoarse, NCoarseElement)

        basisCorrectors = pglod.assembleBasisCorrectors()

        modifiedBasis = basis - basisCorrectors

        xFull = np.zeros(NpCoarse)
        xFull[free] = xFree
        uCoarse = xFull
        uLodFine = modifiedBasis*xFull
        
        #energy error
        errortol = np.sqrt(np.dot(uFineFem - uLodFine, AFine*(uFineFem - uLodFine)))
        
        errorplotinfo.append(errortol)
        tolerancesafe.append(tol)
    
    # 100% updating
    uLodFinebest = uLodFine
    errorbest = np.sqrt(np.dot(uFineFem - uLodFinebest, AFine*(uFineFem - uLodFinebest)))
    
    for k in range(leng-1,-1,-1):
        errorBest.append(errorbest)
        errorWorst.append(errorworst)

    return vis, eps, PotentialCorrectors, recomputefractionsafe, errorplotinfo, errorWorst, errorBest

# %% [markdown]
# ## Preparations
#
# We use the same setting as we have already used before containing the 'buildcoef2d' class in order to construct the coefficient. We visualize the coefficient and store the information in an extern folder.

# %%
bg = 0.05       #background
val = 1         #values

#fine World
NWorldFine = np.array([256, 256])
NpFine = np.prod(NWorldFine+1)                                                                               

#coarse World
NWorldCoarse = np.array([16,16])
NpCoarse = np.prod(NWorldCoarse+1)

#ratio between Fine and Coarse
NCoarseElement = NWorldFine/NWorldCoarse

boundaryConditions = np.array([[0, 0],
                               [0, 0]])

world = World(NWorldCoarse, NCoarseElement, boundaryConditions)

#righthandside
f = np.ones(NpCoarse)

#Coefficient 4
CoefClass = buildcoef2d.Coefficient2d(NWorldFine, 
                        bg                  = bg, 
                        val                 = val, 
                        thick               = 1, 
                        space               = 0, 
                        probfactor          = 1, 
                        right               = 0, 
                        down                = 0, 
                        diagr1              = 1, 
                        diagr2              = 0, 
                        diagl1              = 1, 
                        diagl2              = 0, 
                        LenSwitch           = [4,5,6,7,8], 
                        thickSwitch         = None, 
                        equidistant         = None, 
                        ChannelHorizontal   = None, 
                        ChannelVertical     = None,
                        BoundarySpace       = None) 

A = CoefClass.BuildCoefficient()
ABase = A.flatten()

ROOT = '../test_data/Coef4'

#safe NworldFine
with open("%s/NWorldFine.txt" % ROOT, 'wb') as csvfile:
    writer = csv.writer(csvfile)
    for val in NWorldFine:
        writer.writerow([val])

#safe NworldCoarse
with open("%s/NWorldCoarse.txt" % ROOT, 'wb') as csvfile:
    writer = csv.writer(csvfile)
    for val in NWorldCoarse:
        writer.writerow([val])

#ABase
with open("%s/OriginalCoeff.txt" % ROOT, 'wb') as csvfile:
    writer = csv.writer(csvfile)
    for val in ABase:
        writer.writerow([val])

#fine-fem
f_fine = np.ones(NpFine)
uFineFem, AFine, MFine = femsolver.solveFine(world, ABase, f_fine, None, boundaryConditions)

#fine solution
with open("%s/finescale.txt" % ROOT, 'wb') as csvfile:
    writer = csv.writer(csvfile)
    for val in uFineFem:
        writer.writerow([val])
        
plt.figure("Original")
drawCoefficient(NWorldFine, ABase,greys=True)
plt.title("Original coefficient")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Perturbations of the same entries
#
# To keep comparability, we use the 'specific' perturbation function and use a random seed.

# %%
# random seed
random.seed(20)

# decision
valc = np.shape(CoefClass.ShapeRemember)[0]
numbers = []
decision = np.zeros(100)
decision[0] = 1


for i in range(0,valc):
    a = random.sample(decision,1)[0]
    if a == 1:
        numbers.append(i)

value1 = 3
C1 = CoefClass.SpecificValueChange(ratio=value1,
                                    Number = numbers,
                                    probfactor=1,
                                    randomvalue=None,
                                    negative=None,
                                    ShapeRestriction=True,
                                    ShapeWave=None,
                                    ChangeRight=1,
                                    ChangeDown=1,
                                    ChangeDiagr1=1,
                                    ChangeDiagr2=1,
                                    ChangeDiagl1=1,
                                    ChangeDiagl2=1,
                                    Original = True,
                                    NewShapeChange = True)

V = CoefClass.SpecificVanish(Number = numbers,
                                probfactor=1,
                                PartlyVanish=None,
                                ChangeRight=1,
                                ChangeDown=1,
                                ChangeDiagr1=1,
                                ChangeDiagr2=1,
                                ChangeDiagl1=1,
                                ChangeDiagl2=1,
                                Original = True)

M1 = CoefClass.SpecificMove(probfactor=1,
                            Number = numbers,
                            steps=1,
                            randomstep=None,
                            randomDirection=None,
                            ChangeRight=1,
                            ChangeDown=1,
                            ChangeDiagr1=1,
                            ChangeDiagr2=1,
                            ChangeDiagl1=1,
                            ChangeDiagl2=1,
                            Right=1,
                            BottomRight=0,
                            Bottom=0,
                            BottomLeft=0,
                            Left=0,
                            TopLeft=0,
                            Top=0,
                            TopRight=0,
                            Original = True)

# %% [markdown]
# ## Precomputations

# %%
k = 4

NWorldFine = world.NWorldFine
NWorldCoarse = world.NWorldCoarse
NCoarseElement = world.NCoarseElement

boundaryConditions = world.boundaryConditions
NpFine = np.prod(NWorldFine+1)
NpCoarse = np.prod(NWorldCoarse+1)

#interpolant
IPatchGenerator = lambda i, N: interp.L2ProjectionPatchMatrix(i, N, NWorldCoarse, NCoarseElement, boundaryConditions)

#old Coefficient
ABase = A.flatten()
Aold = coef.coefficientFine(NWorldCoarse, NCoarseElement, ABase)

pglod = pg_rand.VcPetrovGalerkinLOD(Aold, world, k, IPatchGenerator, 0)
pglod.originCorrectors(clearFineQuantities=False)

# %% [markdown]
# ## Change in value

# %%
vis, eps, PotentialUpdated, recomputefractionsafe, errorplotinfo, errorworst, errorb
# epsilonT = 0.0026697092504 C
# epsilonT = 0.0247869633118 C
# epsilonT = 0.0166025983714 C
# epsilonT = 0.0133150069823 C
# epsilonT = 0.00283252587516 C
# epsilonT = 0.000241026996488 C
# epsilonT = 6.85907705266e-05 C
# epsilonT = 0.00271004353379 C
# epsilonT = 0.0270538176163 C
# epsilonT = 0.229881065688 C
# epsilonT = 0.089203388187 C
# epsilonT = 0.00682451263746 C
# Waiting for results 256
# To be recomputed:  100.0 %
#  --- 1/257 --- Tolerance: 0.51961 in Specific value change3 ----  To be recomputed:  0.0 %
#  --- 2/257 --- Tolerance: 0.48072 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 3/257 --- Tolerance: 0.45215 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 4/257 --- Tolerance: 0.44949 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 5/257 --- Tolerance: 0.44142 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 6/257 --- Tolerance: 0.43874 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 7/257 --- Tolerance: 0.43405 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 8/257 --- Tolerance: 0.42938 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 9/257 --- Tolerance: 0.41177 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 10/257 --- Tolerance: 0.40736 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 11/257 --- Tolerance: 0.40486 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 12/257 --- Tolerance: 0.40263 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 13/257 --- Tolerance: 0.40257 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 14/257 --- Tolerance: 0.40053 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 15/257 --- Tolerance: 0.39891 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 16/257 --- Tolerance: 0.39826 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 17/257 --- Tolerance: 0.398 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 18/257 --- Tolerance: 0.39638 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 19/257 --- Tolerance: 0.39355 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 20/257 --- Tolerance: 0.38948 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 21/257 --- Tolerance: 0.38504 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 22/257 --- Tolerance: 0.38438 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 23/257 --- Tolerance: 0.38368 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 24/257 --- Tolerance: 0.38172 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 25/257 --- Tolerance: 0.38108 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 26/257 --- Tolerance: 0.37728 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 27/257 --- Tolerance: 0.37593 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 28/257 --- Tolerance: 0.37089 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 29/257 --- Tolerance: 0.36806 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 30/257 --- Tolerance: 0.36584 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 31/257 --- Tolerance: 0.36568 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 32/257 --- Tolerance: 0.36332 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 33/257 --- Tolerance: 0.35896 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 34/257 --- Tolerance: 0.35643 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 35/257 --- Tolerance: 0.34927 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 36/257 --- Tolerance: 0.33634 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 37/257 --- Tolerance: 0.33218 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 38/257 --- Tolerance: 0.33128 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 39/257 --- Tolerance: 0.32989 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 40/257 --- Tolerance: 0.32578 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 41/257 --- Tolerance: 0.32116 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 42/257 --- Tolerance: 0.3211 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 43/257 --- Tolerance: 0.29394 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 44/257 --- Tolerance: 0.27464 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 45/257 --- Tolerance: 0.27341 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 46/257 --- Tolerance: 0.27223 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 47/257 --- Tolerance: 0.26882 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 48/257 --- Tolerance: 0.26698 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 49/257 --- Tolerance: 0.25574 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 50/257 --- Tolerance: 0.24885 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 51/257 --- Tolerance: 0.24744 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 52/257 --- Tolerance: 0.24038 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 53/257 --- Tolerance: 0.23819 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 54/257 --- Tolerance: 0.23517 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 55/257 --- Tolerance: 0.22988 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 56/257 --- Tolerance: 0.22366 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 57/257 --- Tolerance: 0.20188 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 58/257 --- Tolerance: 0.19674 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 59/257 --- Tolerance: 0.17905 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 60/257 --- Tolerance: 0.16856 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 61/257 --- Tolerance: 0.16129 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 62/257 --- Tolerance: 0.16077 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 63/257 --- Tolerance: 0.15223 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 64/257 --- Tolerance: 0.14015 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 65/257 --- Tolerance: 0.12575 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 66/257 --- Tolerance: 0.11875 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 67/257 --- Tolerance: 0.11459 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 68/257 --- Tolerance: 0.10917 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 69/257 --- Tolerance: 0.0962 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 70/257 --- Tolerance: 0.09615 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 71/257 --- Tolerance: 0.094 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 72/257 --- Tolerance: 0.09047 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 73/257 --- Tolerance: 0.08941 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 74/257 --- Tolerance: 0.0892 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 75/257 --- Tolerance: 0.089 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 76/257 --- Tolerance: 0.08648 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 77/257 --- Tolerance: 0.08353 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 78/257 --- Tolerance: 0.0803 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 79/257 --- Tolerance: 0.07714 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 80/257 --- Tolerance: 0.07689 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 81/257 --- Tolerance: 0.07401 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 82/257 --- Tolerance: 0.07176 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 83/257 --- Tolerance: 0.07137 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 84/257 --- Tolerance: 0.06976 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 85/257 --- Tolerance: 0.06899 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 86/257 --- Tolerance: 0.06787 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 87/257 --- Tolerance: 0.06632 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 88/257 --- Tolerance: 0.06526 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 89/257 --- Tolerance: 0.06487 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 90/257 --- Tolerance: 0.06468 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 91/257 --- Tolerance: 0.06449 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 92/257 --- Tolerance: 0.06297 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 93/257 --- Tolerance: 0.06086 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 94/257 --- Tolerance: 0.05714 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 95/257 --- Tolerance: 0.05654 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 96/257 --- Tolerance: 0.05426 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 97/257 --- Tolerance: 0.05038 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 98/257 --- Tolerance: 0.05003 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 99/257 --- Tolerance: 0.04981 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 100/257 --- Tolerance: 0.04966 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 101/257 --- Tolerance: 0.04936 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 102/257 --- Tolerance: 0.04754 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 103/257 --- Tolerance: 0.04451 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 104/257 --- Tolerance: 0.04425 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 105/257 --- Tolerance: 0.04321 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 106/257 --- Tolerance: 0.04227 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 107/257 --- Tolerance: 0.04209 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 108/257 --- Tolerance: 0.04207 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 109/257 --- Tolerance: 0.04181 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 110/257 --- Tolerance: 0.04157 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 111/257 --- Tolerance: 0.0415 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 112/257 --- Tolerance: 0.04116 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 113/257 --- Tolerance: 0.04069 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 114/257 --- Tolerance: 0.03991 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 115/257 --- Tolerance: 0.03946 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 116/257 --- Tolerance: 0.03925 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 117/257 --- Tolerance: 0.03915 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 118/257 --- Tolerance: 0.03849 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 119/257 --- Tolerance: 0.03802 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 120/257 --- Tolerance: 0.03791 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 121/257 --- Tolerance: 0.03694 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 122/257 --- Tolerance: 0.03652 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 123/257 --- Tolerance: 0.03599 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 124/257 --- Tolerance: 0.03595 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 125/257 --- Tolerance: 0.03585 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 126/257 --- Tolerance: 0.03533 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 127/257 --- Tolerance: 0.03519 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 128/257 --- Tolerance: 0.0343 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 129/257 --- Tolerance: 0.03382 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 130/257 --- Tolerance: 0.03365 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 131/257 --- Tolerance: 0.03326 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 132/257 --- Tolerance: 0.03315 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 133/257 --- Tolerance: 0.03304 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 134/257 --- Tolerance: 0.0329 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 135/257 --- Tolerance: 0.03185 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 136/257 --- Tolerance: 0.03082 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 137/257 --- Tolerance: 0.03079 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 138/257 --- Tolerance: 0.03075 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 139/257 --- Tolerance: 0.03031 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 140/257 --- Tolerance: 0.03027 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 141/257 --- Tolerance: 0.03004 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 142/257 --- Tolerance: 0.02992 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 143/257 --- Tolerance: 0.02947 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 144/257 --- Tolerance: 0.02942 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 145/257 --- Tolerance: 0.02869 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 146/257 --- Tolerance: 0.02847 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 147/257 --- Tolerance: 0.02839 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 148/257 --- Tolerance: 0.02835 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 149/257 --- Tolerance: 0.02821 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 150/257 --- Tolerance: 0.02775 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 151/257 --- Tolerance: 0.02772 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 152/257 --- Tolerance: 0.02705 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 153/257 --- Tolerance: 0.02649 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 154/257 --- Tolerance: 0.02624 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 155/257 --- Tolerance: 0.02621 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 156/257 --- Tolerance: 0.02607 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 157/257 --- Tolerance: 0.02506 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 158/257 --- Tolerance: 0.02493 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 159/257 --- Tolerance: 0.0249 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 160/257 --- Tolerance: 0.02479 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 161/257 --- Tolerance: 0.02458 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 162/257 --- Tolerance: 0.0236 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 163/257 --- Tolerance: 0.02315 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 164/257 --- Tolerance: 0.02154 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 165/257 --- Tolerance: 0.021 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 166/257 --- Tolerance: 0.01953 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 167/257 --- Tolerance: 0.01932 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 168/257 --- Tolerance: 0.01928 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 169/257 --- Tolerance: 0.01755 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 170/257 --- Tolerance: 0.0166 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 171/257 --- Tolerance: 0.01576 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 172/257 --- Tolerance: 0.0152 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 173/257 --- Tolerance: 0.01502 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 174/257 --- Tolerance: 0.01427 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 175/257 --- Tolerance: 0.01427 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 176/257 --- Tolerance: 0.01375 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 177/257 --- Tolerance: 0.01373 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 178/257 --- Tolerance: 0.01355 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 179/257 --- Tolerance: 0.0134 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 180/257 --- Tolerance: 0.01332 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 181/257 --- Tolerance: 0.01177 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 182/257 --- Tolerance: 0.01114 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 183/257 --- Tolerance: 0.01086 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 184/257 --- Tolerance: 0.01036 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 185/257 --- Tolerance: 0.00938 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 186/257 --- Tolerance: 0.00892 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 187/257 --- Tolerance: 0.0088 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 188/257 --- Tolerance: 0.00828 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 189/257 --- Tolerance: 0.00769 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 190/257 --- Tolerance: 0.00682 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 191/257 --- Tolerance: 0.00644 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 192/257 --- Tolerance: 0.0062 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 193/257 --- Tolerance: 0.00591 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 194/257 --- Tolerance: 0.00562 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 195/257 --- Tolerance: 0.00499 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 196/257 --- Tolerance: 0.0045 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 197/257 --- Tolerance: 0.00445 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 198/257 --- Tolerance: 0.00436 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 199/257 --- Tolerance: 0.00423 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 200/257 --- Tolerance: 0.00411 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 201/257 --- Tolerance: 0.00373 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 202/257 --- Tolerance: 0.00372 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 203/257 --- Tolerance: 0.00311 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 204/257 --- Tolerance: 0.00283 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 205/257 --- Tolerance: 0.00275 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 206/257 --- Tolerance: 0.00271 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 207/257 --- Tolerance: 0.00267 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 208/257 --- Tolerance: 0.00254 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 209/257 --- Tolerance: 0.00216 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 210/257 --- Tolerance: 0.00198 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 211/257 --- Tolerance: 0.00187 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 212/257 --- Tolerance: 0.00179 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 213/257 --- Tolerance: 0.0017 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 214/257 --- Tolerance: 0.00161 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 215/257 --- Tolerance: 0.00155 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 216/257 --- Tolerance: 0.00154 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 217/257 --- Tolerance: 0.0015 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 218/257 --- Tolerance: 0.00149 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 219/257 --- Tolerance: 0.00143 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 220/257 --- Tolerance: 0.0012 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 221/257 --- Tolerance: 0.00118 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 222/257 --- Tolerance: 0.00117 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 223/257 --- Tolerance: 0.00116 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 224/257 --- Tolerance: 0.00112 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 225/257 --- Tolerance: 0.00104 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 226/257 --- Tolerance: 0.00099 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 227/257 --- Tolerance: 0.00088 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 228/257 --- Tolerance: 0.00088 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 229/257 --- Tolerance: 0.0008 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 230/257 --- Tolerance: 0.00078 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 231/257 --- Tolerance: 0.00073 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 232/257 --- Tolerance: 0.00064 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 233/257 --- Tolerance: 0.00064 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 234/257 --- Tolerance: 0.00062 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 235/257 --- Tolerance: 0.00057 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 236/257 --- Tolerance: 0.00056 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 237/257 --- Tolerance: 0.00036 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 238/257 --- Tolerance: 0.00035 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 239/257 --- Tolerance: 0.00031 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 240/257 --- Tolerance: 0.00024 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 241/257 --- Tolerance: 0.00018 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 242/257 --- Tolerance: 0.00014 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 243/257 --- Tolerance: 0.00014 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 244/257 --- Tolerance: 0.00013 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 245/257 --- Tolerance: 0.00013 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 246/257 --- Tolerance: 0.00013 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 247/257 --- Tolerance: 0.00012 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 248/257 --- Tolerance: 8e-05 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 249/257 --- Tolerance: 7e-05 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 250/257 --- Tolerance: 7e-05 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 251/257 --- Tolerance: 7e-05 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 252/257 --- Tolerance: 7e-05 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 253/257 --- Tolerance: 7e-05 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 254/257 --- Tolerance: 7e-05 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 255/257 --- Tolerance: 7e-05 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 256/257 --- Tolerance: 6e-05 in Specific value change3 ----  To be recomputed:  0.390625 %
#  --- 257/257 --- Tolerance: 1e-05 in Specific value change3 ----  To be recomputed:  0.390625 %

# %% [markdown]
# ## Disappearance

# %%
vis, eps, PotentialUpdated, recomputefractionsafe, errorplotinfo, errorworst, errorbest = result(pglod ,world, A, V, f, k, 'Vanish')

safeVanish(ROOT, V, vis, eps, PotentialUpdated, recomputefractionsafe, errorplotinfo, errorworst, errorbest)
# Out:
# ------------------------------------- Vanish -------------------------------------------
# Setting up workers
# Done
# epsilonT = 1.40793775463 C
# epsilonT = 0.0942024249621 C
# epsilonT = 0.0234534930714 C
# epsilonT = 0.227449805148 C
# epsilonT = 1.07192585948 C
# epsilonT = 0.209625213125 C
# epsilonT = 0.0497107447989 C
# epsilonT = 0.0553018780537 C
# epsilonT = 0.0127450768977 C
# epsilonT = 0.0141373799424 C
# epsilonT = 0.0857264372368 C
# epsilonT = 0.256244392449 C
# epsilonT = 1.30851563631 C
# epsilonT = 0.272472980936 C
# epsilonT = 0.0293321560069 C
# epsilonT = 0.00207904405733 C
# epsilonT = 0.431172174821 C
# epsilonT = 0.119146279712 C
# epsilonT = 0.111777146503 C
# epsilonT = 0.110885190314 C
# epsilonT = 0.109012022831 C
# epsilonT = 0.0834780504509 C
# epsilonT = 1.30073952148 C
# epsilonT = 0.792136824822 C
# epsilonT = 0.0307674736001 C
# epsilonT = 0.0119944629656 C
# epsilonT = 0.236589611311 C
# epsilonT = 1.26490243921 C
# epsilonT = 0.0902241873417 C
# epsilonT = 0.0871985322405 C
# epsilonT = 0.00560264698537 C
# epsilonT = 0.000864887047153 C
# epsilonT = 0.104635714669 C
# epsilonT = 1.29175011502 C
# epsilonT = 0.828317346493 C
# epsilonT = 0.0123360595568 C
# epsilonT = 0.0957856816866 C
# epsilonT = 0.0935786275548 C
# epsilonT = 0.21847467345 C
# epsilonT = 1.02933781656 C
# epsilonT = 0.842168257811 C
# epsilonT = 0.807324574983 C
# epsilonT = 0.103428404679 C
# epsilonT = 0.0048196822736 C
# epsilonT = 0.000387908286556 C
# epsilonT = 0.000345704476598 C
# epsilonT = 0.00420776993829 C
# epsilonT = 0.0547294577611 C
# epsilonT = 0.0446479418822 C
# epsilonT = 0.0872968803512 C
# epsilonT = 0.0379583076341 C
# epsilonT = 0.00159393569656 C
# epsilonT = 0.00248669621826 C
# epsilonT = 0.00612762285655 C
# epsilonT = 0.0265798880097 C
# epsilonT = 0.0333322613218 C
# epsilonT = 0.45683981418 C
# epsilonT = 1.64736327537 C
# epsilonT = 0.0742410479352 C
# epsilonT = 0.00333787818596 C
# epsilonT = 0.000370579442072 C
# epsilonT = 0.000205015424296 C
# epsilonT = 0.00330674093987 C
# epsilonT = 0.0705226481479 C
# epsilonT = 1.59333881795 C
# epsilonT = 0.244936739006 C
# epsilonT = 0.0217945242761 C
# epsilonT = 0.00020921994049 C
# epsilonT = 0.000202830334754 C
# epsilonT = 0.000354638899396 C
# epsilonT = 0.00161438636157 C
# epsilonT = 0.00756155839447 C
# epsilonT = 0.0702054242332 C
# epsilonT = 0.0470244155112 C
# epsilonT = 0.0377127969288 C
# epsilonT = 0.00802271251285 C
# epsilonT = 0.00068267348151 C
# epsilonT = 0.000194273259 C
# epsilonT = 0.0076757993138 C
# epsilonT = 0.0766259553052 C
# epsilonT = 0.684943441264 C
# epsilonT = 0.252655463759 C
# epsilonT = 0.0193294272828 C
# Waiting for results 256
# To be recomputed:  100.0 %
#  --- 1/257 --- Tolerance: 2.21013 in Vanish ----  To be recomputed:  0.0 %
#  --- 2/257 --- Tolerance: 2.00888 in Vanish ----  To be recomputed:  0.390625 %
#  --- 3/257 --- Tolerance: 1.75917 in Vanish ----  To be recomputed:  0.390625 %
#  --- 4/257 --- Tolerance: 1.68856 in Vanish ----  To be recomputed:  0.390625 %
#  --- 5/257 --- Tolerance: 1.64736 in Vanish ----  To be recomputed:  0.390625 %
#  --- 6/257 --- Tolerance: 1.64261 in Vanish ----  To be recomputed:  0.390625 %
#  --- 7/257 --- Tolerance: 1.59334 in Vanish ----  To be recomputed:  0.390625 %
#  --- 8/257 --- Tolerance: 1.57846 in Vanish ----  To be recomputed:  0.390625 %
#  --- 9/257 --- Tolerance: 1.53796 in Vanish ----  To be recomputed:  0.390625 %
#  --- 10/257 --- Tolerance: 1.48812 in Vanish ----  To be recomputed:  0.390625 %
#  --- 11/257 --- Tolerance: 1.44521 in Vanish ----  To be recomputed:  0.390625 %
#  --- 12/257 --- Tolerance: 1.44459 in Vanish ----  To be recomputed:  0.390625 %
#  --- 13/257 --- Tolerance: 1.41747 in Vanish ----  To be recomputed:  0.390625 %
#  --- 14/257 --- Tolerance: 1.41483 in Vanish ----  To be recomputed:  0.390625 %
#  --- 15/257 --- Tolerance: 1.40794 in Vanish ----  To be recomputed:  0.390625 %
#  --- 16/257 --- Tolerance: 1.40354 in Vanish ----  To be recomputed:  0.390625 %
#  --- 17/257 --- Tolerance: 1.38643 in Vanish ----  To be recomputed:  0.390625 %
#  --- 18/257 --- Tolerance: 1.37231 in Vanish ----  To be recomputed:  0.390625 %
#  --- 19/257 --- Tolerance: 1.33524 in Vanish ----  To be recomputed:  0.390625 %
#  --- 20/257 --- Tolerance: 1.30852 in Vanish ----  To be recomputed:  0.390625 %
#  --- 21/257 --- Tolerance: 1.30074 in Vanish ----  To be recomputed:  0.390625 %
#  --- 22/257 --- Tolerance: 1.29771 in Vanish ----  To be recomputed:  0.390625 %
#  --- 23/257 --- Tolerance: 1.29743 in Vanish ----  To be recomputed:  0.390625 %
#  --- 24/257 --- Tolerance: 1.29443 in Vanish ----  To be recomputed:  0.390625 %
#  --- 25/257 --- Tolerance: 1.29175 in Vanish ----  To be recomputed:  0.390625 %
#  --- 26/257 --- Tolerance: 1.28146 in Vanish ----  To be recomputed:  0.390625 %
#  --- 27/257 --- Tolerance: 1.27029 in Vanish ----  To be recomputed:  0.390625 %
#  --- 28/257 --- Tolerance: 1.2649 in Vanish ----  To be recomputed:  0.390625 %
#  --- 29/257 --- Tolerance: 1.25504 in Vanish ----  To be recomputed:  0.390625 %
#  --- 30/257 --- Tolerance: 1.22307 in Vanish ----  To be recomputed:  0.390625 %
#  --- 31/257 --- Tolerance: 1.21236 in Vanish ----  To be recomputed:  0.390625 %
#  --- 32/257 --- Tolerance: 1.20506 in Vanish ----  To be recomputed:  0.390625 %
#  --- 33/257 --- Tolerance: 1.20158 in Vanish ----  To be recomputed:  0.390625 %
#  --- 34/257 --- Tolerance: 1.16956 in Vanish ----  To be recomputed:  0.390625 %
#  --- 35/257 --- Tolerance: 1.13694 in Vanish ----  To be recomputed:  0.390625 %
#  --- 36/257 --- Tolerance: 1.12526 in Vanish ----  To be recomputed:  0.390625 %
#  --- 37/257 --- Tolerance: 1.12325 in Vanish ----  To be recomputed:  0.390625 %
#  --- 38/257 --- Tolerance: 1.07417 in Vanish ----  To be recomputed:  0.390625 %
#  --- 39/257 --- Tolerance: 1.07193 in Vanish ----  To be recomputed:  0.390625 %
#  --- 40/257 --- Tolerance: 1.02934 in Vanish ----  To be recomputed:  0.390625 %
#  --- 41/257 --- Tolerance: 1.02767 in Vanish ----  To be recomputed:  0.390625 %
#  --- 42/257 --- Tolerance: 1.01087 in Vanish ----  To be recomputed:  0.390625 %
#  --- 43/257 --- Tolerance: 0.94942 in Vanish ----  To be recomputed:  0.390625 %
#  --- 44/257 --- Tolerance: 0.84217 in Vanish ----  To be recomputed:  0.390625 %
#  --- 45/257 --- Tolerance: 0.83413 in Vanish ----  To be recomputed:  0.390625 %
#  --- 46/257 --- Tolerance: 0.82832 in Vanish ----  To be recomputed:  0.390625 %
#  --- 47/257 --- Tolerance: 0.80732 in Vanish ----  To be recomputed:  0.390625 %
#  --- 48/257 --- Tolerance: 0.79214 in Vanish ----  To be recomputed:  0.390625 %
#  --- 49/257 --- Tolerance: 0.77839 in Vanish ----  To be recomputed:  0.390625 %
#  --- 50/257 --- Tolerance: 0.73352 in Vanish ----  To be recomputed:  0.390625 %
#  --- 51/257 --- Tolerance: 0.73072 in Vanish ----  To be recomputed:  0.390625 %
#  --- 52/257 --- Tolerance: 0.72266 in Vanish ----  To be recomputed:  0.390625 %
#  --- 53/257 --- Tolerance: 0.69603 in Vanish ----  To be recomputed:  0.390625 %
#  --- 54/257 --- Tolerance: 0.69054 in Vanish ----  To be recomputed:  0.390625 %
#  --- 55/257 --- Tolerance: 0.68494 in Vanish ----  To be recomputed:  0.390625 %
#  --- 56/257 --- Tolerance: 0.67007 in Vanish ----  To be recomputed:  0.390625 %
#  --- 57/257 --- Tolerance: 0.59221 in Vanish ----  To be recomputed:  0.390625 %
#  --- 58/257 --- Tolerance: 0.55725 in Vanish ----  To be recomputed:  0.390625 %
#  --- 59/257 --- Tolerance: 0.50713 in Vanish ----  To be recomputed:  0.390625 %
#  --- 60/257 --- Tolerance: 0.49259 in Vanish ----  To be recomputed:  0.390625 %
#  --- 61/257 --- Tolerance: 0.45684 in Vanish ----  To be recomputed:  0.390625 %
#  --- 62/257 --- Tolerance: 0.45537 in Vanish ----  To be recomputed:  0.390625 %
#  --- 63/257 --- Tolerance: 0.43117 in Vanish ----  To be recomputed:  0.390625 %
#  --- 64/257 --- Tolerance: 0.39695 in Vanish ----  To be recomputed:  0.390625 %
#  --- 65/257 --- Tolerance: 0.35617 in Vanish ----  To be recomputed:  0.390625 %
#  --- 66/257 --- Tolerance: 0.33633 in Vanish ----  To be recomputed:  0.390625 %
#  --- 67/257 --- Tolerance: 0.32455 in Vanish ----  To be recomputed:  0.390625 %
#  --- 68/257 --- Tolerance: 0.30921 in Vanish ----  To be recomputed:  0.390625 %
#  --- 69/257 --- Tolerance: 0.27247 in Vanish ----  To be recomputed:  0.390625 %
#  --- 70/257 --- Tolerance: 0.27234 in Vanish ----  To be recomputed:  0.390625 %
#  --- 71/257 --- Tolerance: 0.26625 in Vanish ----  To be recomputed:  0.390625 %
#  --- 72/257 --- Tolerance: 0.25624 in Vanish ----  To be recomputed:  0.390625 %
#  --- 73/257 --- Tolerance: 0.25324 in Vanish ----  To be recomputed:  0.390625 %
#  --- 74/257 --- Tolerance: 0.25266 in Vanish ----  To be recomputed:  0.390625 %
#  --- 75/257 --- Tolerance: 0.25208 in Vanish ----  To be recomputed:  0.390625 %
#  --- 76/257 --- Tolerance: 0.24494 in Vanish ----  To be recomputed:  0.390625 %
#  --- 77/257 --- Tolerance: 0.23659 in Vanish ----  To be recomputed:  0.390625 %
#  --- 78/257 --- Tolerance: 0.22745 in Vanish ----  To be recomputed:  0.390625 %
#  --- 79/257 --- Tolerance: 0.21847 in Vanish ----  To be recomputed:  0.390625 %
#  --- 80/257 --- Tolerance: 0.21777 in Vanish ----  To be recomputed:  0.390625 %
#  --- 81/257 --- Tolerance: 0.20963 in Vanish ----  To be recomputed:  0.390625 %
#  --- 82/257 --- Tolerance: 0.20325 in Vanish ----  To be recomputed:  0.390625 %
#  --- 83/257 --- Tolerance: 0.20214 in Vanish ----  To be recomputed:  0.390625 %
#  --- 84/257 --- Tolerance: 0.19759 in Vanish ----  To be recomputed:  0.390625 %
#  --- 85/257 --- Tolerance: 0.19542 in Vanish ----  To be recomputed:  0.390625 %
#  --- 86/257 --- Tolerance: 0.19223 in Vanish ----  To be recomputed:  0.390625 %
#  --- 87/257 --- Tolerance: 0.18783 in Vanish ----  To be recomputed:  0.390625 %
#  --- 88/257 --- Tolerance: 0.18484 in Vanish ----  To be recomputed:  0.390625 %
#  --- 89/257 --- Tolerance: 0.18373 in Vanish ----  To be recomputed:  0.390625 %
#  --- 90/257 --- Tolerance: 0.18319 in Vanish ----  To be recomputed:  0.390625 %
#  --- 91/257 --- Tolerance: 0.18266 in Vanish ----  To be recomputed:  0.390625 %
#  --- 92/257 --- Tolerance: 0.17836 in Vanish ----  To be recomputed:  0.390625 %
#  --- 93/257 --- Tolerance: 0.17238 in Vanish ----  To be recomputed:  0.390625 %
#  --- 94/257 --- Tolerance: 0.16185 in Vanish ----  To be recomputed:  0.390625 %
#  --- 95/257 --- Tolerance: 0.16013 in Vanish ----  To be recomputed:  0.390625 %
#  --- 96/257 --- Tolerance: 0.15369 in Vanish ----  To be recomputed:  0.390625 %
#  --- 97/257 --- Tolerance: 0.14269 in Vanish ----  To be recomputed:  0.390625 %
#  --- 98/257 --- Tolerance: 0.14171 in Vanish ----  To be recomputed:  0.390625 %
#  --- 99/257 --- Tolerance: 0.14107 in Vanish ----  To be recomputed:  0.390625 %
#  --- 100/257 --- Tolerance: 0.14065 in Vanish ----  To be recomputed:  0.390625 %
#  --- 101/257 --- Tolerance: 0.13979 in Vanish ----  To be recomputed:  0.390625 %
#  --- 102/257 --- Tolerance: 0.13465 in Vanish ----  To be recomputed:  0.390625 %
#  --- 103/257 --- Tolerance: 0.12606 in Vanish ----  To be recomputed:  0.390625 %
#  --- 104/257 --- Tolerance: 0.12533 in Vanish ----  To be recomputed:  0.390625 %
#  --- 105/257 --- Tolerance: 0.12239 in Vanish ----  To be recomputed:  0.390625 %
#  --- 106/257 --- Tolerance: 0.11972 in Vanish ----  To be recomputed:  0.390625 %
#  --- 107/257 --- Tolerance: 0.1192 in Vanish ----  To be recomputed:  0.390625 %
#  --- 108/257 --- Tolerance: 0.11915 in Vanish ----  To be recomputed:  0.390625 %
#  --- 109/257 --- Tolerance: 0.11843 in Vanish ----  To be recomputed:  0.390625 %
#  --- 110/257 --- Tolerance: 0.11774 in Vanish ----  To be recomputed:  0.390625 %
#  --- 111/257 --- Tolerance: 0.11754 in Vanish ----  To be recomputed:  0.390625 %
#  --- 112/257 --- Tolerance: 0.11658 in Vanish ----  To be recomputed:  0.390625 %
#  --- 113/257 --- Tolerance: 0.11523 in Vanish ----  To be recomputed:  0.390625 %
#  --- 114/257 --- Tolerance: 0.11305 in Vanish ----  To be recomputed:  0.390625 %
#  --- 115/257 --- Tolerance: 0.11178 in Vanish ----  To be recomputed:  0.390625 %
#  --- 116/257 --- Tolerance: 0.11116 in Vanish ----  To be recomputed:  0.390625 %
#  --- 117/257 --- Tolerance: 0.11089 in Vanish ----  To be recomputed:  0.390625 %
#  --- 118/257 --- Tolerance: 0.10901 in Vanish ----  To be recomputed:  0.390625 %
#  --- 119/257 --- Tolerance: 0.10769 in Vanish ----  To be recomputed:  0.390625 %
#  --- 120/257 --- Tolerance: 0.10738 in Vanish ----  To be recomputed:  0.390625 %
#  --- 121/257 --- Tolerance: 0.10464 in Vanish ----  To be recomputed:  0.390625 %
#  --- 122/257 --- Tolerance: 0.10343 in Vanish ----  To be recomputed:  0.390625 %
#  --- 123/257 --- Tolerance: 0.10195 in Vanish ----  To be recomputed:  0.390625 %
#  --- 124/257 --- Tolerance: 0.10183 in Vanish ----  To be recomputed:  0.390625 %
#  --- 125/257 --- Tolerance: 0.10154 in Vanish ----  To be recomputed:  0.390625 %
#  --- 126/257 --- Tolerance: 0.10006 in Vanish ----  To be recomputed:  0.390625 %
#  --- 127/257 --- Tolerance: 0.09967 in Vanish ----  To be recomputed:  0.390625 %
#  --- 128/257 --- Tolerance: 0.09716 in Vanish ----  To be recomputed:  0.390625 %
#  --- 129/257 --- Tolerance: 0.09579 in Vanish ----  To be recomputed:  0.390625 %
#  --- 130/257 --- Tolerance: 0.09531 in Vanish ----  To be recomputed:  0.390625 %
#  --- 131/257 --- Tolerance: 0.0942 in Vanish ----  To be recomputed:  0.390625 %
#  --- 132/257 --- Tolerance: 0.09389 in Vanish ----  To be recomputed:  0.390625 %
#  --- 133/257 --- Tolerance: 0.09358 in Vanish ----  To be recomputed:  0.390625 %
#  --- 134/257 --- Tolerance: 0.09319 in Vanish ----  To be recomputed:  0.390625 %
#  --- 135/257 --- Tolerance: 0.09022 in Vanish ----  To be recomputed:  0.390625 %
#  --- 136/257 --- Tolerance: 0.0873 in Vanish ----  To be recomputed:  0.390625 %
#  --- 137/257 --- Tolerance: 0.0872 in Vanish ----  To be recomputed:  0.390625 %
#  --- 138/257 --- Tolerance: 0.08708 in Vanish ----  To be recomputed:  0.390625 %
#  --- 139/257 --- Tolerance: 0.08585 in Vanish ----  To be recomputed:  0.390625 %
#  --- 140/257 --- Tolerance: 0.08573 in Vanish ----  To be recomputed:  0.390625 %
#  --- 141/257 --- Tolerance: 0.08508 in Vanish ----  To be recomputed:  0.390625 %
#  --- 142/257 --- Tolerance: 0.08475 in Vanish ----  To be recomputed:  0.390625 %
#  --- 143/257 --- Tolerance: 0.08348 in Vanish ----  To be recomputed:  0.390625 %
#  --- 144/257 --- Tolerance: 0.08332 in Vanish ----  To be recomputed:  0.390625 %
#  --- 145/257 --- Tolerance: 0.08126 in Vanish ----  To be recomputed:  0.390625 %
#  --- 146/257 --- Tolerance: 0.08064 in Vanish ----  To be recomputed:  0.390625 %
#  --- 147/257 --- Tolerance: 0.0804 in Vanish ----  To be recomputed:  0.390625 %
#  --- 148/257 --- Tolerance: 0.08029 in Vanish ----  To be recomputed:  0.390625 %
#  --- 149/257 --- Tolerance: 0.07989 in Vanish ----  To be recomputed:  0.390625 %
#  --- 150/257 --- Tolerance: 0.0786 in Vanish ----  To be recomputed:  0.390625 %
#  --- 151/257 --- Tolerance: 0.07851 in Vanish ----  To be recomputed:  0.390625 %
#  --- 152/257 --- Tolerance: 0.07663 in Vanish ----  To be recomputed:  0.390625 %
#  --- 153/257 --- Tolerance: 0.07504 in Vanish ----  To be recomputed:  0.390625 %
#  --- 154/257 --- Tolerance: 0.07433 in Vanish ----  To be recomputed:  0.390625 %
#  --- 155/257 --- Tolerance: 0.07424 in Vanish ----  To be recomputed:  0.390625 %
#  --- 156/257 --- Tolerance: 0.07383 in Vanish ----  To be recomputed:  0.390625 %
#  --- 157/257 --- Tolerance: 0.07098 in Vanish ----  To be recomputed:  0.390625 %
#  --- 158/257 --- Tolerance: 0.07062 in Vanish ----  To be recomputed:  0.390625 %
#  --- 159/257 --- Tolerance: 0.07052 in Vanish ----  To be recomputed:  0.390625 %
#  --- 160/257 --- Tolerance: 0.07021 in Vanish ----  To be recomputed:  0.390625 %
#  --- 161/257 --- Tolerance: 0.06961 in Vanish ----  To be recomputed:  0.390625 %
#  --- 162/257 --- Tolerance: 0.06685 in Vanish ----  To be recomputed:  0.390625 %
#  --- 163/257 --- Tolerance: 0.06558 in Vanish ----  To be recomputed:  0.390625 %
#  --- 164/257 --- Tolerance: 0.06101 in Vanish ----  To be recomputed:  0.390625 %
#  --- 165/257 --- Tolerance: 0.05948 in Vanish ----  To be recomputed:  0.390625 %
#  --- 166/257 --- Tolerance: 0.0553 in Vanish ----  To be recomputed:  0.390625 %
#  --- 167/257 --- Tolerance: 0.05473 in Vanish ----  To be recomputed:  0.390625 %
#  --- 168/257 --- Tolerance: 0.05461 in Vanish ----  To be recomputed:  0.390625 %
#  --- 169/257 --- Tolerance: 0.04971 in Vanish ----  To be recomputed:  0.390625 %
#  --- 170/257 --- Tolerance: 0.04702 in Vanish ----  To be recomputed:  0.390625 %
#  --- 171/257 --- Tolerance: 0.04465 in Vanish ----  To be recomputed:  0.390625 %
#  --- 172/257 --- Tolerance: 0.04304 in Vanish ----  To be recomputed:  0.390625 %
#  --- 173/257 --- Tolerance: 0.04253 in Vanish ----  To be recomputed:  0.390625 %
#  --- 174/257 --- Tolerance: 0.04043 in Vanish ----  To be recomputed:  0.390625 %
#  --- 175/257 --- Tolerance: 0.04042 in Vanish ----  To be recomputed:  0.390625 %
#  --- 176/257 --- Tolerance: 0.03895 in Vanish ----  To be recomputed:  0.390625 %
#  --- 177/257 --- Tolerance: 0.03889 in Vanish ----  To be recomputed:  0.390625 %
#  --- 178/257 --- Tolerance: 0.03838 in Vanish ----  To be recomputed:  0.390625 %
#  --- 179/257 --- Tolerance: 0.03796 in Vanish ----  To be recomputed:  0.390625 %
#  --- 180/257 --- Tolerance: 0.03771 in Vanish ----  To be recomputed:  0.390625 %
#  --- 181/257 --- Tolerance: 0.03333 in Vanish ----  To be recomputed:  0.390625 %
#  --- 182/257 --- Tolerance: 0.03154 in Vanish ----  To be recomputed:  0.390625 %
#  --- 183/257 --- Tolerance: 0.03077 in Vanish ----  To be recomputed:  0.390625 %
#  --- 184/257 --- Tolerance: 0.02933 in Vanish ----  To be recomputed:  0.390625 %
#  --- 185/257 --- Tolerance: 0.02658 in Vanish ----  To be recomputed:  0.390625 %
#  --- 186/257 --- Tolerance: 0.02528 in Vanish ----  To be recomputed:  0.390625 %
#  --- 187/257 --- Tolerance: 0.02493 in Vanish ----  To be recomputed:  0.390625 %
#  --- 188/257 --- Tolerance: 0.02345 in Vanish ----  To be recomputed:  0.390625 %
#  --- 189/257 --- Tolerance: 0.02179 in Vanish ----  To be recomputed:  0.390625 %
#  --- 190/257 --- Tolerance: 0.01933 in Vanish ----  To be recomputed:  0.390625 %
#  --- 191/257 --- Tolerance: 0.01825 in Vanish ----  To be recomputed:  0.390625 %
#  --- 192/257 --- Tolerance: 0.01755 in Vanish ----  To be recomputed:  0.390625 %
#  --- 193/257 --- Tolerance: 0.01675 in Vanish ----  To be recomputed:  0.390625 %
#  --- 194/257 --- Tolerance: 0.01593 in Vanish ----  To be recomputed:  0.390625 %
#  --- 195/257 --- Tolerance: 0.01414 in Vanish ----  To be recomputed:  0.390625 %
#  --- 196/257 --- Tolerance: 0.01275 in Vanish ----  To be recomputed:  0.390625 %
#  --- 197/257 --- Tolerance: 0.0126 in Vanish ----  To be recomputed:  0.390625 %
#  --- 198/257 --- Tolerance: 0.01234 in Vanish ----  To be recomputed:  0.390625 %
#  --- 199/257 --- Tolerance: 0.01199 in Vanish ----  To be recomputed:  0.390625 %
#  --- 200/257 --- Tolerance: 0.01165 in Vanish ----  To be recomputed:  0.390625 %
#  --- 201/257 --- Tolerance: 0.01057 in Vanish ----  To be recomputed:  0.390625 %
#  --- 202/257 --- Tolerance: 0.01054 in Vanish ----  To be recomputed:  0.390625 %
#  --- 203/257 --- Tolerance: 0.00881 in Vanish ----  To be recomputed:  0.390625 %
#  --- 204/257 --- Tolerance: 0.00802 in Vanish ----  To be recomputed:  0.390625 %
#  --- 205/257 --- Tolerance: 0.00778 in Vanish ----  To be recomputed:  0.390625 %
#  --- 206/257 --- Tolerance: 0.00768 in Vanish ----  To be recomputed:  0.390625 %
#  --- 207/257 --- Tolerance: 0.00756 in Vanish ----  To be recomputed:  0.390625 %
#  --- 208/257 --- Tolerance: 0.0072 in Vanish ----  To be recomputed:  0.390625 %
#  --- 209/257 --- Tolerance: 0.00613 in Vanish ----  To be recomputed:  0.390625 %
#  --- 210/257 --- Tolerance: 0.0056 in Vanish ----  To be recomputed:  0.390625 %
#  --- 211/257 --- Tolerance: 0.00531 in Vanish ----  To be recomputed:  0.390625 %
#  --- 212/257 --- Tolerance: 0.00506 in Vanish ----  To be recomputed:  0.390625 %
#  --- 213/257 --- Tolerance: 0.00482 in Vanish ----  To be recomputed:  0.390625 %
#  --- 214/257 --- Tolerance: 0.00457 in Vanish ----  To be recomputed:  0.390625 %
#  --- 215/257 --- Tolerance: 0.0044 in Vanish ----  To be recomputed:  0.390625 %
#  --- 216/257 --- Tolerance: 0.00436 in Vanish ----  To be recomputed:  0.390625 %
#  --- 217/257 --- Tolerance: 0.00424 in Vanish ----  To be recomputed:  0.390625 %
#  --- 218/257 --- Tolerance: 0.00421 in Vanish ----  To be recomputed:  0.390625 %
#  --- 219/257 --- Tolerance: 0.00405 in Vanish ----  To be recomputed:  0.390625 %
#  --- 220/257 --- Tolerance: 0.0034 in Vanish ----  To be recomputed:  0.390625 %
#  --- 221/257 --- Tolerance: 0.00334 in Vanish ----  To be recomputed:  0.390625 %
#  --- 222/257 --- Tolerance: 0.00331 in Vanish ----  To be recomputed:  0.390625 %
#  --- 223/257 --- Tolerance: 0.0033 in Vanish ----  To be recomputed:  0.390625 %
#  --- 224/257 --- Tolerance: 0.00317 in Vanish ----  To be recomputed:  0.390625 %
#  --- 225/257 --- Tolerance: 0.00296 in Vanish ----  To be recomputed:  0.390625 %
#  --- 226/257 --- Tolerance: 0.00281 in Vanish ----  To be recomputed:  0.390625 %
#  --- 227/257 --- Tolerance: 0.00251 in Vanish ----  To be recomputed:  0.390625 %
#  --- 228/257 --- Tolerance: 0.00249 in Vanish ----  To be recomputed:  0.390625 %
#  --- 229/257 --- Tolerance: 0.00228 in Vanish ----  To be recomputed:  0.390625 %
#  --- 230/257 --- Tolerance: 0.00222 in Vanish ----  To be recomputed:  0.390625 %
#  --- 231/257 --- Tolerance: 0.00208 in Vanish ----  To be recomputed:  0.390625 %
#  --- 232/257 --- Tolerance: 0.00182 in Vanish ----  To be recomputed:  0.390625 %
#  --- 233/257 --- Tolerance: 0.0018 in Vanish ----  To be recomputed:  0.390625 %
#  --- 234/257 --- Tolerance: 0.00174 in Vanish ----  To be recomputed:  0.390625 %
#  --- 235/257 --- Tolerance: 0.00161 in Vanish ----  To be recomputed:  0.390625 %
#  --- 236/257 --- Tolerance: 0.00159 in Vanish ----  To be recomputed:  0.390625 %
#  --- 237/257 --- Tolerance: 0.00102 in Vanish ----  To be recomputed:  0.390625 %
#  --- 238/257 --- Tolerance: 0.00098 in Vanish ----  To be recomputed:  0.390625 %
#  --- 239/257 --- Tolerance: 0.00086 in Vanish ----  To be recomputed:  0.390625 %
#  --- 240/257 --- Tolerance: 0.00068 in Vanish ----  To be recomputed:  0.390625 %
#  --- 241/257 --- Tolerance: 0.00052 in Vanish ----  To be recomputed:  0.390625 %
#  --- 242/257 --- Tolerance: 0.00039 in Vanish ----  To be recomputed:  0.390625 %
#  --- 243/257 --- Tolerance: 0.00039 in Vanish ----  To be recomputed:  0.390625 %
#  --- 244/257 --- Tolerance: 0.00038 in Vanish ----  To be recomputed:  0.390625 %
#  --- 245/257 --- Tolerance: 0.00037 in Vanish ----  To be recomputed:  0.390625 %
#  --- 246/257 --- Tolerance: 0.00035 in Vanish ----  To be recomputed:  0.390625 %
#  --- 247/257 --- Tolerance: 0.00035 in Vanish ----  To be recomputed:  0.390625 %
#  --- 248/257 --- Tolerance: 0.00023 in Vanish ----  To be recomputed:  0.390625 %
#  --- 249/257 --- Tolerance: 0.00021 in Vanish ----  To be recomputed:  0.390625 %
#  --- 250/257 --- Tolerance: 0.00021 in Vanish ----  To be recomputed:  0.390625 %
#  --- 251/257 --- Tolerance: 0.0002 in Vanish ----  To be recomputed:  0.390625 %
#  --- 252/257 --- Tolerance: 0.0002 in Vanish ----  To be recomputed:  0.390625 %
#  --- 253/257 --- Tolerance: 0.0002 in Vanish ----  To be recomputed:  0.390625 %
#  --- 254/257 --- Tolerance: 0.00019 in Vanish ----  To be recomputed:  0.390625 %
#  --- 255/257 --- Tolerance: 0.00019 in Vanish ----  To be recomputed:  0.390625 %
#  --- 256/257 --- Tolerance: 0.00017 in Vanish ----  To be recomputed:  0.390625 %
#  --- 257/257 --- Tolerance: 0.0001 in Vanish ----  To be recomputed:  0.390625 %

# %% [markdown]
# ## Shift

# %%
vis, eps, PotentialUpdated, recomputefractionsafe, errorplotinfo, errorworst, errorbest = result(pglod ,world, A, M1, f, k, 'One Step Move')

safeShift(ROOT, M1, vis, eps, PotentialUpdated, recomputefractionsafe, errorplotinfo, errorworst, errorbest)
# Out:
# ------------------------------------- One Step Move -------------------------------------------
# Setting up workers
# Done
# epsilonT = 1.07964326001 C
# epsilonT = 0.0751197183454 C
# epsilonT = 0.0196778367855 C
# epsilonT = 0.182406000149 C
# epsilonT = 0.837764463597 C
# epsilonT = 0.155439178125 C
# epsilonT = 0.0423005661606 C
# epsilonT = 0.0482007921794 C
# epsilonT = 0.0088073166328 C
# epsilonT = 0.0113583033561 C
# epsilonT = 0.067420608525 C
# epsilonT = 0.219417922149 C
# epsilonT = 0.955995697802 C
# epsilonT = 0.204376530564 C
# epsilonT = 0.0217288392677 C
# epsilonT = 0.00155928261462 C
# epsilonT = 0.350440182047 C
# epsilonT = 0.0933452591427 C
# epsilonT = 0.0834016235792 C
# epsilonT = 0.0943560785965 C
# epsilonT = 0.0896832265542 C
# epsilonT = 0.0646882780234 C
# epsilonT = 1.0348340996 C
# epsilonT = 0.490145521566 C
# epsilonT = 0.0260343083204 C
# epsilonT = 0.00991908634321 C
# epsilonT = 0.198925046466 C
# epsilonT = 1.02132547443 C
# epsilonT = 0.0749794767548 C
# epsilonT = 0.061625143148 C
# epsilonT = 0.00405508550905 C
# epsilonT = 0.000615971199545 C
# epsilonT = 0.0584436489412 C
# epsilonT = 1.20188272318 C
# epsilonT = 0.427201575054 C
# epsilonT = 0.106113628616 C
# epsilonT = 0.0968029206558 C
# epsilonT = 0.0481504036795 C
# epsilonT = 0.199413291789 C
# epsilonT = 0.797798831819 C
# epsilonT = 0.801598467219 C
# epsilonT = 0.551775026841 C
# epsilonT = 0.0745525454855 C
# epsilonT = 0.00383335918072 C
# epsilonT = 0.00029514592802 C
# epsilonT = 0.000269945890609 C
# epsilonT = 0.00419580333835 C
# epsilonT = 0.0443818519826 C
# epsilonT = 0.0497512796097 C
# epsilonT = 0.0921694495038 C
# epsilonT = 0.029836722394 C
# epsilonT = 0.00130588234851 C
# epsilonT = 0.00204505292594 C
# epsilonT = 0.00571888987835 C
# epsilonT = 0.0221592042512 C
# epsilonT = 0.0257141803752 C
# epsilonT = 0.41252349827 C
# epsilonT = 1.16420591572 C
# epsilonT = 0.0501057050594 C
# epsilonT = 0.0026630875897 C
# epsilonT = 0.000291120379412 C
# epsilonT = 0.000207330311825 C
# epsilonT = 0.00282956961256 C
# epsilonT = 0.0710000296418 C
# epsilonT = 1.08466161496 C
# epsilonT = 0.220087637288 C
# epsilonT = 0.0195142437155 C
# epsilonT = 0.000180332514782 C
# epsilonT = 0.000181561713512 C
# epsilonT = 0.00029729744846 C
# epsilonT = 0.00129668213864 C
# epsilonT = 0.00605854789821 C
# epsilonT = 0.0562698034564 C
# epsilonT = 0.041854690111 C
# epsilonT = 0.0288022419354 C
# epsilonT = 0.00601172599414 C
# epsilonT = 0.000448603284256 C
# epsilonT = 0.000174470111554 C
# epsilonT = 0.00683938056999 C
# epsilonT = 0.0673826783993 C
# epsilonT = 0.647139824009 C
# epsilonT = 0.209196358924 C
# epsilonT = 0.0155921047785 C
# Waiting for results 256
# To be recomputed:  100.0 %
#  --- 1/257 --- Tolerance: 1.54787 in One Step Move ----  To be recomputed:  0.0 %
#  --- 2/257 --- Tolerance: 1.35581 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 3/257 --- Tolerance: 1.23402 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 4/257 --- Tolerance: 1.21509 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 5/257 --- Tolerance: 1.20188 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 6/257 --- Tolerance: 1.18173 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 7/257 --- Tolerance: 1.18046 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 8/257 --- Tolerance: 1.16421 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 9/257 --- Tolerance: 1.13549 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 10/257 --- Tolerance: 1.13014 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 11/257 --- Tolerance: 1.12177 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 12/257 --- Tolerance: 1.10029 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 13/257 --- Tolerance: 1.09447 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 14/257 --- Tolerance: 1.08694 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 15/257 --- Tolerance: 1.08474 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 16/257 --- Tolerance: 1.08466 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 17/257 --- Tolerance: 1.07964 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 18/257 --- Tolerance: 1.06278 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 19/257 --- Tolerance: 1.05001 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 20/257 --- Tolerance: 1.04816 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 21/257 --- Tolerance: 1.03808 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 22/257 --- Tolerance: 1.03483 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 23/257 --- Tolerance: 1.02519 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 24/257 --- Tolerance: 1.02133 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 25/257 --- Tolerance: 1.00684 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 26/257 --- Tolerance: 0.96059 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 27/257 --- Tolerance: 0.956 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 28/257 --- Tolerance: 0.95554 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 29/257 --- Tolerance: 0.95263 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 30/257 --- Tolerance: 0.94371 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 31/257 --- Tolerance: 0.93852 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 32/257 --- Tolerance: 0.92753 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 33/257 --- Tolerance: 0.9253 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 34/257 --- Tolerance: 0.88196 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 35/257 --- Tolerance: 0.87849 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 36/257 --- Tolerance: 0.85242 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 37/257 --- Tolerance: 0.84972 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 38/257 --- Tolerance: 0.83776 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 39/257 --- Tolerance: 0.82631 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 40/257 --- Tolerance: 0.82111 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 41/257 --- Tolerance: 0.81875 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 42/257 --- Tolerance: 0.8016 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 43/257 --- Tolerance: 0.7978 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 44/257 --- Tolerance: 0.72899 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 45/257 --- Tolerance: 0.71194 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 46/257 --- Tolerance: 0.67714 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 47/257 --- Tolerance: 0.65314 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 48/257 --- Tolerance: 0.65167 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 49/257 --- Tolerance: 0.65114 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 50/257 --- Tolerance: 0.64714 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 51/257 --- Tolerance: 0.61091 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 52/257 --- Tolerance: 0.58403 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 53/257 --- Tolerance: 0.56424 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 54/257 --- Tolerance: 0.55178 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 55/257 --- Tolerance: 0.53952 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 56/257 --- Tolerance: 0.50211 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 57/257 --- Tolerance: 0.49015 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 58/257 --- Tolerance: 0.46943 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 59/257 --- Tolerance: 0.46773 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 60/257 --- Tolerance: 0.4272 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 61/257 --- Tolerance: 0.41856 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 62/257 --- Tolerance: 0.41252 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 63/257 --- Tolerance: 0.35044 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 64/257 --- Tolerance: 0.34723 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 65/257 --- Tolerance: 0.30206 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 66/257 --- Tolerance: 0.27912 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 67/257 --- Tolerance: 0.2676 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 68/257 --- Tolerance: 0.23391 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 69/257 --- Tolerance: 0.22276 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 70/257 --- Tolerance: 0.22009 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 71/257 --- Tolerance: 0.21942 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 72/257 --- Tolerance: 0.21406 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 73/257 --- Tolerance: 0.21319 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 74/257 --- Tolerance: 0.21021 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 75/257 --- Tolerance: 0.2092 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 76/257 --- Tolerance: 0.20542 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 77/257 --- Tolerance: 0.20438 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 78/257 --- Tolerance: 0.19941 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 79/257 --- Tolerance: 0.19893 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 80/257 --- Tolerance: 0.18241 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 81/257 --- Tolerance: 0.17904 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 82/257 --- Tolerance: 0.16817 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 83/257 --- Tolerance: 0.16719 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 84/257 --- Tolerance: 0.15985 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 85/257 --- Tolerance: 0.15688 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 86/257 --- Tolerance: 0.15544 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 87/257 --- Tolerance: 0.15371 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 88/257 --- Tolerance: 0.15317 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 89/257 --- Tolerance: 0.14929 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 90/257 --- Tolerance: 0.14879 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 91/257 --- Tolerance: 0.14312 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 92/257 --- Tolerance: 0.14148 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 93/257 --- Tolerance: 0.1402 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 94/257 --- Tolerance: 0.13898 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 95/257 --- Tolerance: 0.12932 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 96/257 --- Tolerance: 0.12325 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 97/257 --- Tolerance: 0.11605 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 98/257 --- Tolerance: 0.11513 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 99/257 --- Tolerance: 0.11161 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 100/257 --- Tolerance: 0.11131 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 101/257 --- Tolerance: 0.10788 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 102/257 --- Tolerance: 0.10773 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 103/257 --- Tolerance: 0.10611 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 104/257 --- Tolerance: 0.10429 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 105/257 --- Tolerance: 0.10295 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 106/257 --- Tolerance: 0.10191 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 107/257 --- Tolerance: 0.10133 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 108/257 --- Tolerance: 0.10026 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 109/257 --- Tolerance: 0.09801 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 110/257 --- Tolerance: 0.09739 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 111/257 --- Tolerance: 0.0968 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 112/257 --- Tolerance: 0.09585 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 113/257 --- Tolerance: 0.09436 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 114/257 --- Tolerance: 0.09335 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 115/257 --- Tolerance: 0.09312 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 116/257 --- Tolerance: 0.09292 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 117/257 --- Tolerance: 0.09217 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 118/257 --- Tolerance: 0.08968 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 119/257 --- Tolerance: 0.08867 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 120/257 --- Tolerance: 0.08761 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 121/257 --- Tolerance: 0.08496 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 122/257 --- Tolerance: 0.08452 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 123/257 --- Tolerance: 0.0845 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 124/257 --- Tolerance: 0.08429 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 125/257 --- Tolerance: 0.0834 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 126/257 --- Tolerance: 0.08148 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 127/257 --- Tolerance: 0.08127 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 128/257 --- Tolerance: 0.08126 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 129/257 --- Tolerance: 0.07728 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 130/257 --- Tolerance: 0.07668 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 131/257 --- Tolerance: 0.07544 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 132/257 --- Tolerance: 0.07512 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 133/257 --- Tolerance: 0.07498 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 134/257 --- Tolerance: 0.07455 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 135/257 --- Tolerance: 0.07443 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 136/257 --- Tolerance: 0.07266 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 137/257 --- Tolerance: 0.07108 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 138/257 --- Tolerance: 0.07102 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 139/257 --- Tolerance: 0.071 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 140/257 --- Tolerance: 0.0704 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 141/257 --- Tolerance: 0.06973 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 142/257 --- Tolerance: 0.06919 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 143/257 --- Tolerance: 0.06903 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 144/257 --- Tolerance: 0.06774 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 145/257 --- Tolerance: 0.06742 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 146/257 --- Tolerance: 0.06742 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 147/257 --- Tolerance: 0.06738 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 148/257 --- Tolerance: 0.06498 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 149/257 --- Tolerance: 0.06482 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 150/257 --- Tolerance: 0.06469 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 151/257 --- Tolerance: 0.06401 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 152/257 --- Tolerance: 0.064 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 153/257 --- Tolerance: 0.06298 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 154/257 --- Tolerance: 0.06186 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 155/257 --- Tolerance: 0.06163 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 156/257 --- Tolerance: 0.06125 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 157/257 --- Tolerance: 0.06069 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 158/257 --- Tolerance: 0.06029 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 159/257 --- Tolerance: 0.05844 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 160/257 --- Tolerance: 0.05739 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 161/257 --- Tolerance: 0.05627 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 162/257 --- Tolerance: 0.05504 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 163/257 --- Tolerance: 0.05077 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 164/257 --- Tolerance: 0.05011 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 165/257 --- Tolerance: 0.04975 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 166/257 --- Tolerance: 0.0482 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 167/257 --- Tolerance: 0.04815 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 168/257 --- Tolerance: 0.04753 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 169/257 --- Tolerance: 0.04678 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 170/257 --- Tolerance: 0.04438 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 171/257 --- Tolerance: 0.0423 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 172/257 --- Tolerance: 0.04185 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 173/257 --- Tolerance: 0.03803 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 174/257 --- Tolerance: 0.03601 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 175/257 --- Tolerance: 0.03443 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 176/257 --- Tolerance: 0.03436 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 177/257 --- Tolerance: 0.0343 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 178/257 --- Tolerance: 0.03379 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 179/257 --- Tolerance: 0.02984 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 180/257 --- Tolerance: 0.02895 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 181/257 --- Tolerance: 0.0288 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 182/257 --- Tolerance: 0.02603 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 183/257 --- Tolerance: 0.02571 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 184/257 --- Tolerance: 0.02237 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 185/257 --- Tolerance: 0.02216 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 186/257 --- Tolerance: 0.02173 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 187/257 --- Tolerance: 0.01995 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 188/257 --- Tolerance: 0.01968 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 189/257 --- Tolerance: 0.01951 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 190/257 --- Tolerance: 0.01559 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 191/257 --- Tolerance: 0.01481 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 192/257 --- Tolerance: 0.01397 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 193/257 --- Tolerance: 0.01317 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 194/257 --- Tolerance: 0.01305 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 195/257 --- Tolerance: 0.01136 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 196/257 --- Tolerance: 0.01004 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 197/257 --- Tolerance: 0.00998 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 198/257 --- Tolerance: 0.00992 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 199/257 --- Tolerance: 0.00962 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 200/257 --- Tolerance: 0.00923 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 201/257 --- Tolerance: 0.00881 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 202/257 --- Tolerance: 0.00796 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 203/257 --- Tolerance: 0.00708 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 204/257 --- Tolerance: 0.00684 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 205/257 --- Tolerance: 0.00654 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 206/257 --- Tolerance: 0.00653 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 207/257 --- Tolerance: 0.00606 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 208/257 --- Tolerance: 0.00601 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 209/257 --- Tolerance: 0.00572 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 210/257 --- Tolerance: 0.00447 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 211/257 --- Tolerance: 0.00427 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 212/257 --- Tolerance: 0.00423 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 213/257 --- Tolerance: 0.0042 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 214/257 --- Tolerance: 0.00411 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 215/257 --- Tolerance: 0.00406 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 216/257 --- Tolerance: 0.00383 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 217/257 --- Tolerance: 0.00373 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 218/257 --- Tolerance: 0.00346 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 219/257 --- Tolerance: 0.00328 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 220/257 --- Tolerance: 0.00283 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 221/257 --- Tolerance: 0.00266 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 222/257 --- Tolerance: 0.00262 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 223/257 --- Tolerance: 0.00257 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 224/257 --- Tolerance: 0.00254 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 225/257 --- Tolerance: 0.00248 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 226/257 --- Tolerance: 0.00216 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 227/257 --- Tolerance: 0.00205 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 228/257 --- Tolerance: 0.00202 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 229/257 --- Tolerance: 0.0018 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 230/257 --- Tolerance: 0.00168 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 231/257 --- Tolerance: 0.00156 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 232/257 --- Tolerance: 0.00151 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 233/257 --- Tolerance: 0.00147 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 234/257 --- Tolerance: 0.00146 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 235/257 --- Tolerance: 0.00131 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 236/257 --- Tolerance: 0.0013 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 237/257 --- Tolerance: 0.00092 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 238/257 --- Tolerance: 0.00087 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 239/257 --- Tolerance: 0.00062 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 240/257 --- Tolerance: 0.00045 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 241/257 --- Tolerance: 0.00038 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 242/257 --- Tolerance: 0.00033 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 243/257 --- Tolerance: 0.0003 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 244/257 --- Tolerance: 0.0003 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 245/257 --- Tolerance: 0.0003 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 246/257 --- Tolerance: 0.00029 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 247/257 --- Tolerance: 0.00027 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 248/257 --- Tolerance: 0.00021 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 249/257 --- Tolerance: 0.00019 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 250/257 --- Tolerance: 0.00018 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 251/257 --- Tolerance: 0.00018 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 252/257 --- Tolerance: 0.00017 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 253/257 --- Tolerance: 0.00017 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 254/257 --- Tolerance: 0.00016 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 255/257 --- Tolerance: 0.00016 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 256/257 --- Tolerance: 0.00015 in One Step Move ----  To be recomputed:  0.390625 %
#  --- 257/257 --- Tolerance: 0.0001 in One Step Move ----  To be recomputed:  0.390625 %
