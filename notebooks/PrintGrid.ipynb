# %%
import os
import sys

sys.path.append(os.getcwd() + '/../generate_figures')

# %% [markdown]
# # Print patch
#
# This will print ... as in ... $yes$

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

# %%
from PrintGrid import Patchprint1

Patchprint1()
# Out:
# <img src="data:image/png;base64,..." width="640">
