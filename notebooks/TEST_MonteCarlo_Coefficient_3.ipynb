# %% [markdown]
# # Monte Carlo simulation for Coefficient 3

# %%
import os
import sys
import numpy as np
import scipy.sparse as sparse
import scipy.stats as stats
import random
import csv

# %matplotlib notebook
import matplotlib.pyplot as plt
from visualize import drawCoefficient
from data import * 

from gridlod import interp, coef, util, fem, world, linalg, femsolver
import pg_rand, femsolverCoarse, buildcoef2d
from gridlod.world import World

# %% [markdown]
# ## Result function

# %%
def result(pglod, world, CoefClass, A, f, MC=1, prob=100):
    NWorldFine = world.NWorldFine
    NWorldCoarse = world.NWorldCoarse
    NCoarseElement = world.NCoarseElement
    
    boundaryConditions = world.boundaryConditions
    NpFine = np.prod(NWorldFine+1)
    NpCoarse = np.prod(NWorldCoarse+1)
    
    plist = [0,5,10,20,30,100]
    
    #### initial #####
    xmLoda = np.zeros([MC,np.size(plist)])
    xmVcLoda = np.zeros([MC,np.size(plist)])
    xmLodVcLoda = np.zeros([MC,np.size(plist)])
    
    ems = []
    
    plottingx = np.zeros([MC-1,np.size(plist)])
    plottingy = np.zeros([MC-1,np.size(plist)])
    plottingz = np.zeros([MC-1,np.size(plist)])
        
    plotting2x = np.zeros([MC-1,np.size(plist)])
    plotting2y = np.zeros([MC-1,np.size(plist)])
    plotting2z = np.zeros([MC-1,np.size(plist)])
    
    plotting3x = np.zeros([MC-1,np.size(plist)])
    plotting3y = np.zeros([MC-1,np.size(plist)])
    plotting3z = np.zeros([MC-1,np.size(plist)])

    for i in range(0,MC):
        print '_____Sample__ ' + str(i+1) + '/' + str(MC) + ' ____' 
        R = CoefClass.RandomVanish( probfactor      = prob,
                                    PartlyVanish    = None,
                                    Original        = True)
        
        ANew = R.flatten()
        
        ###### Reference solution ######
        f_fine = np.ones(NpFine)
        uFineFem, AFine, MFine = femsolver.solveFine(world, ANew, f_fine, None, boundaryConditions)
        
        Anew = coef.coefficientFine(NWorldCoarse, NCoarseElement, ANew)
        
        ###### tolerance = 0 without computing ######
        vis, eps = pglod.updateCorrectors(Anew, 0, f, 1, clearFineQuantities=False, mc=True, Computing=None)
        print 'Affected correctors: ' + str(np.sum(vis))
        
        ##### VCLOD ######
        uVc = []
        updated = 0
        for p in plist:
            print 'p = ' + str(p) + '%',
            uVcLod, updated = VcLod(pglod, world, Anew, eps, updated, numberofcorrectors=p)
            if p == 100:
                uLod = uVcLod
                pglod.CorrectorsToOrigin()
            else:
                uVc.append(uVcLod)
        
        for k in range(0,np.shape(uVc)[0]):
            uVcLod = uVc[k]
            eVcLod = np.sqrt(np.dot(uFineFem - uVcLod, MFine*(uFineFem - uVcLod))) / np.sqrt(np.dot(uFineFem, MFine*uFineFem))
            eLodVcLod = np.sqrt(np.dot(uVcLod - uLod, MFine*(uVcLod - uLod))) / np.sqrt(np.dot(uLod, MFine*uLod))
            eLod = np.sqrt(np.dot(uFineFem - uLod, MFine*(uFineFem - uLod))) / np.sqrt(np.dot(uFineFem, MFine*uFineFem))
            
            xmLoda[i,k] = eLod
            xmVcLoda[i,k] = eVcLod
            xmLodVcLoda[i,k] = eLodVcLod
           
        if i == 0:
            continue
        ems.append(i+1)
        
        for k in range(0,np.shape(uVc)[0]):
            muLod = 0
            muVcLod = 0
            muLodVcLod = 0
            for j in range(0,i+1):
                muLod += xmLoda[j,k]
                muVcLod += xmVcLoda[j,k]
                muLodVcLod += xmLodVcLoda[j,k]
    
            muLod /= i+1
            muVcLod /= i+1
            muLodVcLod /= i+1
    
            sig2Lod = 0
            sig2VcLod = 0
            sig2LodVcLod = 0
    
            for j in range(0,i+1):
                sig2Lod += (xmLoda[j,k]-muLod)**(2)
                sig2VcLod += (xmVcLoda[j,k]-muVcLod)**(2)
                sig2LodVcLod += (xmLodVcLoda[j,k]-muLodVcLod)**(2)
        
            sig2Lod /= i
            sig2VcLod /= i
            sig2LodVcLod /= i
    
            a = [np.sqrt(sig2Lod)/np.sqrt(i+1)*1.96,np.sqrt(sig2VcLod)/np.sqrt(i+1)*1.96,np.sqrt(sig2LodVcLod)/np.sqrt(i+1)*1.96]
            mum = [muLod,muVcLod,muLodVcLod]
            
            plottingx[i-1,k] = mum[0]-a[0]
            plottingy[i-1,k] = mum[0]
            plottingz[i-1,k] = mum[0]+a[0]
        
            plotting2x[i-1,k] = mum[1]-a[1]
            plotting2y[i-1,k] = mum[1]
            plotting2z[i-1,k] = mum[1]+a[1]

            plotting3x[i-1,k] = mum[2]-a[2]
            plotting3y[i-1,k] = mum[2]
            plotting3z[i-1,k] = mum[2]+a[2]
            
            Matrix = CoefClass.Matrix.flatten()
            ROOT = '../test_data/MonteCarlo/Coef3/p' + str(100/prob) + '/' + str(plist[k]) 
            safer(ROOT, mum, a, plottingx[:,k], plottingy[:,k], plottingz[:,k], plotting2x[:,k], plotting2y[:,k], plotting2z[:,k], plotting3x[:,k], plotting3y[:,k], plotting3z[:,k], ems, Matrix)
        
    return a,mum

# %% [markdown]
# ## VC-LOD

# %%
def VcLod(pglod, world, Anew, eps, updated = 0,
    numberofcorrectors=5):
    NWorldFine = world.NWorldFine
    NWorldCoarse = world.NWorldCoarse
    NCoarseElement = world.NCoarseElement

    boundaryConditions = world.boundaryConditions
    NpFine = np.prod(NWorldFine+1)
    NpCoarse = np.prod(NWorldCoarse+1)

    ##### tolerance = certain ######
    eps = filter(lambda x: x!=0, eps)
    eps.sort()
    epssize = np.size(eps)
    until = int(round((numberofcorrectors/100. * epssize) +0.49,0))
    if epssize != 0:
        until = int(round((until * 256./epssize)+0.49,0))
    tolrev = []
    for i in range(epssize-1,-1,-1):
        tolrev.append(eps[i])
    
    if epssize == 0:
        print 'nothing to update'
    else:
        if until >= epssize:
            tol = 0
        else:
            tol = tolrev[until]
        vistol = pglod.updateCorrectors(Anew, tol, f, clearFineQuantities=False, mc=True, Testing=True)
        updated += np.sum(vistol)
        print 'Updated correctors: ' + str(updated)
        
    KFull = pglod.assembleMsStiffnessMatrix()
    MFull = fem.assemblePatchMatrix(NWorldCoarse, world.MLocCoarse)
    free  = util.interiorpIndexMap(NWorldCoarse)
   
    bFull = MFull*f
    KFree = KFull[free][:,free]
    bFree = bFull[free]

    xFree = sparse.linalg.spsolve(KFree, bFree)
    basis = fem.assembleProlongationMatrix(NWorldCoarse, NCoarseElement)

    basisCorrectors = pglod.assembleBasisCorrectors()
    modifiedBasis = basis - basisCorrectors

    xFull = np.zeros(NpCoarse)
    xFull[free] = xFree
    uCoarse = xFull
    uVcLod = modifiedBasis*xFull

    return uVcLod, updated

# %%
#background
bg = 0.05
#values
val = 1
random.seed(20)
#fine World
NWorldFine = np.array([256, 256])
NpFine = np.prod(NWorldFine+1)                                                                               

#coarse World
NWorldCoarse = np.array([16,16])
NpCoarse = np.prod(NWorldCoarse+1)

#ratio between Fine and Coarse
NCoarseElement = NWorldFine/NWorldCoarse

boundaryConditions = np.array([[0, 0],
                               [0, 0]])

world = World(NWorldCoarse, NCoarseElement, boundaryConditions)

#righthandside
f = np.ones(NpCoarse)

#coefficient 3
CoefClass = buildcoef2d.Coefficient2d(NWorldFine, 
                        bg                  = bg, 
                        val                 = val, 
                        length              = 8, 
                        thick               = 2, 
                        space               = 4, 
                        probfactor          = 1, 
                        right               = 0, 
                        down                = 0, 
                        diagr1              = 0, 
                        diagr2              = 0, 
                        diagl1              = 0, 
                        diagl2              = 1, 
                        LenSwitch           = None, 
                        thickSwitch         = None, 
                        equidistant         = None, 
                        ChannelHorizontal   = None, 
                        ChannelVertical     = None,
                        BoundarySpace       = True)


A = CoefClass.BuildCoefficient()
ABase = A.flatten()
        
plt.figure("OriginalCoefficient")
drawCoefficient(NWorldFine, ABase)
plt.title('Original coefficient')

k = 4

###### precompute #######
NWorldFine = world.NWorldFine
NWorldCoarse = world.NWorldCoarse
NCoarseElement = world.NCoarseElement

boundaryConditions = world.boundaryConditions
NpFine = np.prod(NWorldFine+1)
NpCoarse = np.prod(NWorldCoarse+1)

#interpolant
IPatchGenerator = lambda i, N: interp.L2ProjectionPatchMatrix(i, N, NWorldCoarse, NCoarseElement, boundaryConditions)

#old Coefficient (need flatten form)
ABase = A.flatten()
Aold = coef.coefficientFine(NWorldCoarse, NCoarseElement, ABase)

pglod = pg_rand.VcPetrovGalerkinLOD(Aold, world, k, IPatchGenerator, 0)
pglod.originCorrectors(clearFineQuantities=False)

#Perturbations
print '_____________ 1% Perturbations __________'
prob = 100

MC = 100
a, mum = result(pglod, world, CoefClass, A, f, MC, prob)

#Perturbations
print '_____________ 2% Perturbations __________'
prob = 50

MC = 100
a, mum = result(pglod, world, CoefClass, A, f, MC, prob)
# Out:
# <img src="data:image/png;base64,..." width="640">
# _____________ 1% Perturbations __________
# _____Sample__ 1/100 ____
# Not Recomputed!
# Affected correctors: 227.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 227.0
# _____Sample__ 2/100 ____
# Not Recomputed!
# Affected correctors: 187.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 79.0
# p = 100% Updated correctors: 187.0
# _____Sample__ 3/100 ____
# Not Recomputed!
# Affected correctors: 213.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 213.0
# _____Sample__ 4/100 ____
# Not Recomputed!
# Affected correctors: 251.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 251.0
# _____Sample__ 5/100 ____
# Not Recomputed!
# Affected correctors: 180.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 180.0
# _____Sample__ 6/100 ____
# Not Recomputed!
# Affected correctors: 199.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 199.0
# _____Sample__ 7/100 ____
# Not Recomputed!
# Affected correctors: 158.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 158.0
# _____Sample__ 8/100 ____
# Not Recomputed!
# Affected correctors: 161.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 15.0
# p = 10% Updated correctors: 28.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 161.0
# _____Sample__ 9/100 ____
# Not Recomputed!
# Affected correctors: 171.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 171.0
# _____Sample__ 10/100 ____
# Not Recomputed!
# Affected correctors: 218.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 218.0
# _____Sample__ 11/100 ____
# Not Recomputed!
# Affected correctors: 240.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 240.0
# _____Sample__ 12/100 ____
# Not Recomputed!
# Affected correctors: 152.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 152.0
# _____Sample__ 13/100 ____
# Not Recomputed!
# Affected correctors: 157.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 79.0
# p = 100% Updated correctors: 157.0
# _____Sample__ 14/100 ____
# Not Recomputed!
# Affected correctors: 208.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 208.0
# _____Sample__ 15/100 ____
# Not Recomputed!
# Affected correctors: 139.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 139.0
# _____Sample__ 16/100 ____
# Not Recomputed!
# Affected correctors: 205.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 205.0
# _____Sample__ 17/100 ____
# Not Recomputed!
# Affected correctors: 238.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 238.0
# _____Sample__ 18/100 ____
# Not Recomputed!
# Affected correctors: 245.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 245.0
# _____Sample__ 19/100 ____
# Not Recomputed!
# Affected correctors: 183.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 183.0
# _____Sample__ 20/100 ____
# Not Recomputed!
# Affected correctors: 238.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 238.0
# _____Sample__ 21/100 ____
# Not Recomputed!
# Affected correctors: 150.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 150.0
# _____Sample__ 22/100 ____
# Not Recomputed!
# Affected correctors: 254.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 254.0
# _____Sample__ 23/100 ____
# Not Recomputed!
# Affected correctors: 200.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 200.0
# _____Sample__ 24/100 ____
# Not Recomputed!
# Affected correctors: 172.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 172.0
# _____Sample__ 25/100 ____
# Not Recomputed!
# Affected correctors: 102.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 16.0
# p = 10% Updated correctors: 28.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 102.0
# _____Sample__ 26/100 ____
# Not Recomputed!
# Affected correctors: 162.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 15.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 162.0
# _____Sample__ 27/100 ____
# Not Recomputed!
# Affected correctors: 184.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 184.0
# _____Sample__ 28/100 ____
# Not Recomputed!
# Affected correctors: 224.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 224.0
# _____Sample__ 29/100 ____
# Not Recomputed!
# Affected correctors: 180.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 180.0
# _____Sample__ 30/100 ____
# Not Recomputed!
# Affected correctors: 244.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 244.0
# _____Sample__ 31/100 ____
# Not Recomputed!
# Affected correctors: 141.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 15.0
# p = 10% Updated correctors: 28.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 79.0
# p = 100% Updated correctors: 141.0
# _____Sample__ 32/100 ____
# Not Recomputed!
# Affected correctors: 196.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 196.0
# _____Sample__ 33/100 ____
# Not Recomputed!
# Affected correctors: 144.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 15.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 79.0
# p = 100% Updated correctors: 144.0
# _____Sample__ 34/100 ____
# Not Recomputed!
# Affected correctors: 205.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 205.0
# _____Sample__ 35/100 ____
# Not Recomputed!
# Affected correctors: 223.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 223.0
# _____Sample__ 36/100 ____
# Not Recomputed!
# Affected correctors: 192.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 192.0
# _____Sample__ 37/100 ____
# Not Recomputed!
# Affected correctors: 147.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 79.0
# p = 100% Updated correctors: 147.0
# _____Sample__ 38/100 ____
# Not Recomputed!
# Affected correctors: 162.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 15.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 162.0
# _____Sample__ 39/100 ____
# Not Recomputed!
# Affected correctors: 205.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 205.0
# _____Sample__ 40/100 ____
# Not Recomputed!
# Affected correctors: 245.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 245.0
# _____Sample__ 41/100 ____
# Not Recomputed!
# Affected correctors: 224.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 224.0
# _____Sample__ 42/100 ____
# Not Recomputed!
# Affected correctors: 186.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 186.0
# _____Sample__ 43/100 ____
# Not Recomputed!
# Affected correctors: 152.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 152.0
# _____Sample__ 44/100 ____
# Not Recomputed!
# Affected correctors: 180.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 180.0
# _____Sample__ 45/100 ____
# Not Recomputed!
# Affected correctors: 202.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 202.0
# _____Sample__ 46/100 ____
# Not Recomputed!
# Affected correctors: 184.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 184.0
# _____Sample__ 47/100 ____
# Not Recomputed!
# Affected correctors: 150.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 150.0
# _____Sample__ 48/100 ____
# Not Recomputed!
# Affected correctors: 225.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 225.0
# _____Sample__ 49/100 ____
# Not Recomputed!
# Affected correctors: 214.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 214.0
# _____Sample__ 50/100 ____
# Not Recomputed!
# Affected correctors: 231.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 231.0
# _____Sample__ 51/100 ____
# Not Recomputed!
# Affected correctors: 199.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 199.0
# _____Sample__ 52/100 ____
# Not Recomputed!
# Affected correctors: 185.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 185.0
# _____Sample__ 53/100 ____
# Not Recomputed!
# Affected correctors: 111.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 28.0
# p = 20% Updated correctors: 54.0
# p = 30% Updated correctors: 79.0
# p = 100% Updated correctors: 111.0
# _____Sample__ 54/100 ____
# Not Recomputed!
# Affected correctors: 104.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 15.0
# p = 10% Updated correctors: 28.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 79.0
# p = 100% Updated correctors: 104.0
# _____Sample__ 55/100 ____
# Not Recomputed!
# Affected correctors: 236.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 236.0
# _____Sample__ 56/100 ____
# Not Recomputed!
# Affected correctors: 188.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 188.0
# _____Sample__ 57/100 ____
# Not Recomputed!
# Affected correctors: 180.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 180.0
# _____Sample__ 58/100 ____
# Not Recomputed!
# Affected correctors: 222.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 222.0
# _____Sample__ 59/100 ____
# Not Recomputed!
# Affected correctors: 175.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 175.0
# _____Sample__ 60/100 ____
# Not Recomputed!
# Affected correctors: 167.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 79.0
# p = 100% Updated correctors: 167.0
# _____Sample__ 61/100 ____
# Not Recomputed!
# Affected correctors: 177.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 79.0
# p = 100% Updated correctors: 177.0
# _____Sample__ 62/100 ____
# Not Recomputed!
# Affected correctors: 210.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 210.0
# _____Sample__ 63/100 ____
# Not Recomputed!
# Affected correctors: 215.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 215.0
# _____Sample__ 64/100 ____
# Not Recomputed!
# Affected correctors: 182.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 15.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 182.0
# _____Sample__ 65/100 ____
# Not Recomputed!
# Affected correctors: 180.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 180.0
# _____Sample__ 66/100 ____
# Not Recomputed!
# Affected correctors: 149.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 149.0
# _____Sample__ 67/100 ____
# Not Recomputed!
# Affected correctors: 218.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 218.0
# _____Sample__ 68/100 ____
# Not Recomputed!
# Affected correctors: 235.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 235.0
# _____Sample__ 69/100 ____
# Not Recomputed!
# Affected correctors: 238.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 238.0
# _____Sample__ 70/100 ____
# Not Recomputed!
# Affected correctors: 191.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 191.0
# _____Sample__ 71/100 ____
# Not Recomputed!
# Affected correctors: 206.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 206.0
# _____Sample__ 72/100 ____
# Not Recomputed!
# Affected correctors: 225.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 225.0
# _____Sample__ 73/100 ____
# Not Recomputed!
# Affected correctors: 248.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 248.0
# _____Sample__ 74/100 ____
# Not Recomputed!
# Affected correctors: 108.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 15.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 79.0
# p = 100% Updated correctors: 108.0
# _____Sample__ 75/100 ____
# Not Recomputed!
# Affected correctors: 214.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 214.0
# _____Sample__ 76/100 ____
# Not Recomputed!
# Affected correctors: 210.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 210.0
# _____Sample__ 77/100 ____
# Not Recomputed!
# Affected correctors: 247.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 247.0
# _____Sample__ 78/100 ____
# Not Recomputed!
# Affected correctors: 248.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 248.0
# _____Sample__ 79/100 ____
# Not Recomputed!
# Affected correctors: 192.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 192.0
# _____Sample__ 80/100 ____
# Not Recomputed!
# Affected correctors: 163.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 15.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 163.0
# _____Sample__ 81/100 ____
# Not Recomputed!
# Affected correctors: 49.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 16.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 49.0
# p = 30% Updated correctors: 49.0
# p = 100% Updated correctors: 49.0
# _____Sample__ 82/100 ____
# Not Recomputed!
# Affected correctors: 235.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 235.0
# _____Sample__ 83/100 ____
# Not Recomputed!
# Affected correctors: 129.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 129.0
# _____Sample__ 84/100 ____
# Not Recomputed!
# Affected correctors: 220.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 220.0
# _____Sample__ 85/100 ____
# Not Recomputed!
# Affected correctors: 256.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 256.0
# _____Sample__ 86/100 ____
# Not Recomputed!
# Affected correctors: 248.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 248.0
# _____Sample__ 87/100 ____
# Not Recomputed!
# Affected correctors: 110.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 110.0
# _____Sample__ 88/100 ____
# Not Recomputed!
# Affected correctors: 201.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 201.0
# _____Sample__ 89/100 ____
# Not Recomputed!
# Affected correctors: 148.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 148.0
# _____Sample__ 90/100 ____
# Not Recomputed!
# Affected correctors: 202.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 202.0
# _____Sample__ 91/100 ____
# Not Recomputed!
# Affected correctors: 226.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 226.0
# _____Sample__ 92/100 ____
# Not Recomputed!
# Affected correctors: 164.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 15.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 79.0
# p = 100% Updated correctors: 164.0
# _____Sample__ 93/100 ____
# Not Recomputed!
# Affected correctors: 251.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 251.0
# _____Sample__ 94/100 ____
# Not Recomputed!
# Affected correctors: 88.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 15.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 79.0
# p = 100% Updated correctors: 88.0
# _____Sample__ 95/100 ____
# Not Recomputed!
# Affected correctors: 112.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 28.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 112.0
# _____Sample__ 96/100 ____
# Not Recomputed!
# Affected correctors: 212.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 212.0
# _____Sample__ 97/100 ____
# Not Recomputed!
# Affected correctors: 165.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 165.0
# _____Sample__ 98/100 ____
# Not Recomputed!
# Affected correctors: 45.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 18.0
# p = 10% Updated correctors: 29.0
# p = 20% Updated correctors: 45.0
# p = 30% Updated correctors: 45.0
# p = 100% Updated correctors: 45.0
# _____Sample__ 99/100 ____
# Not Recomputed!
# Affected correctors: 166.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 166.0
# _____Sample__ 100/100 ____
# Not Recomputed!
# Affected correctors: 48.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 16.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 48.0
# p = 30% Updated correctors: 48.0
# p = 100% Updated correctors: 48.0
# _____________ 2% Perturbations __________
# _____Sample__ 1/100 ____
# Not Recomputed!
# Affected correctors: 256.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 256.0
# _____Sample__ 2/100 ____
# Not Recomputed!
# Affected correctors: 236.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 236.0
# _____Sample__ 3/100 ____
# Not Recomputed!
# Affected correctors: 223.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 223.0
# _____Sample__ 4/100 ____
# Not Recomputed!
# Affected correctors: 176.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 176.0
# _____Sample__ 5/100 ____
# Not Recomputed!
# Affected correctors: 244.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 244.0
# _____Sample__ 6/100 ____
# Not Recomputed!
# Affected correctors: 176.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 176.0
# _____Sample__ 7/100 ____
# Not Recomputed!
# Affected correctors: 255.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 255.0
# _____Sample__ 8/100 ____
# Not Recomputed!
# Affected correctors: 221.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 221.0
# _____Sample__ 9/100 ____
# Not Recomputed!
# Affected correctors: 233.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 233.0
# _____Sample__ 10/100 ____
# Not Recomputed!
# Affected correctors: 253.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 253.0
# _____Sample__ 11/100 ____
# Not Recomputed!
# Affected correctors: 255.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 255.0
# _____Sample__ 12/100 ____
# Not Recomputed!
# Affected correctors: 247.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 247.0
# _____Sample__ 13/100 ____
# Not Recomputed!
# Affected correctors: 229.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 229.0
# _____Sample__ 14/100 ____
# Not Recomputed!
# Affected correctors: 256.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 256.0
# _____Sample__ 15/100 ____
# Not Recomputed!
# Affected correctors: 208.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 208.0
# _____Sample__ 16/100 ____
# Not Recomputed!
# Affected correctors: 254.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 254.0
# _____Sample__ 17/100 ____
# Not Recomputed!
# Affected correctors: 245.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 245.0
# _____Sample__ 18/100 ____
# Not Recomputed!
# Affected correctors: 248.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 248.0
# _____Sample__ 19/100 ____
# Not Recomputed!
# Affected correctors: 238.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 238.0
# _____Sample__ 20/100 ____
# Not Recomputed!
# Affected correctors: 230.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 230.0
# _____Sample__ 21/100 ____
# Not Recomputed!
# Affected correctors: 240.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 240.0
# _____Sample__ 22/100 ____
# Not Recomputed!
# Affected correctors: 237.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 237.0
# _____Sample__ 23/100 ____
# Not Recomputed!
# Affected correctors: 231.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 231.0
# _____Sample__ 24/100 ____
# Not Recomputed!
# Affected correctors: 156.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 156.0
# _____Sample__ 25/100 ____
# Not Recomputed!
# Affected correctors: 221.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 221.0
# _____Sample__ 26/100 ____
# Not Recomputed!
# Affected correctors: 244.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 244.0
# _____Sample__ 27/100 ____
# Not Recomputed!
# Affected correctors: 241.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 241.0
# _____Sample__ 28/100 ____
# Not Recomputed!
# Affected correctors: 242.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 242.0
# _____Sample__ 29/100 ____
# Not Recomputed!
# Affected correctors: 233.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 233.0
# _____Sample__ 30/100 ____
# Not Recomputed!
# Affected correctors: 191.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 191.0
# _____Sample__ 31/100 ____
# Not Recomputed!
# Affected correctors: 251.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 251.0
# _____Sample__ 32/100 ____
# Not Recomputed!
# Affected correctors: 254.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 254.0
# _____Sample__ 33/100 ____
# Not Recomputed!
# Affected correctors: 226.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 226.0
# _____Sample__ 34/100 ____
# Not Recomputed!
# Affected correctors: 218.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 218.0
# _____Sample__ 35/100 ____
# Not Recomputed!
# Affected correctors: 212.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 212.0
# _____Sample__ 36/100 ____
# Not Recomputed!
# Affected correctors: 232.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 232.0
# _____Sample__ 37/100 ____
# Not Recomputed!
# Affected correctors: 252.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 252.0
# _____Sample__ 38/100 ____
# Not Recomputed!
# Affected correctors: 218.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 218.0
# _____Sample__ 39/100 ____
# Not Recomputed!
# Affected correctors: 206.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 206.0
# _____Sample__ 40/100 ____
# Not Recomputed!
# Affected correctors: 256.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 256.0
# _____Sample__ 41/100 ____
# Not Recomputed!
# Affected correctors: 209.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 209.0
# _____Sample__ 42/100 ____
# Not Recomputed!
# Affected correctors: 252.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 252.0
# _____Sample__ 43/100 ____
# Not Recomputed!
# Affected correctors: 223.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 223.0
# _____Sample__ 44/100 ____
# Not Recomputed!
# Affected correctors: 175.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 175.0
# _____Sample__ 45/100 ____
# Not Recomputed!
# Affected correctors: 211.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 211.0
# _____Sample__ 46/100 ____
# Not Recomputed!
# Affected correctors: 249.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 249.0
# _____Sample__ 47/100 ____
# Not Recomputed!
# Affected correctors: 198.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 198.0
# _____Sample__ 48/100 ____
# Not Recomputed!
# Affected correctors: 194.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 194.0
# _____Sample__ 49/100 ____
# Not Recomputed!
# Affected correctors: 232.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 232.0
# _____Sample__ 50/100 ____
# Not Recomputed!
# Affected correctors: 251.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 251.0
# _____Sample__ 51/100 ____
# Not Recomputed!
# Affected correctors: 226.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 226.0
# _____Sample__ 52/100 ____
# Not Recomputed!
# Affected correctors: 242.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 242.0
# _____Sample__ 53/100 ____
# Not Recomputed!
# Affected correctors: 227.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 227.0
# _____Sample__ 54/100 ____
# Not Recomputed!
# Affected correctors: 216.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 216.0
# _____Sample__ 55/100 ____
# Not Recomputed!
# Affected correctors: 238.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 238.0
# _____Sample__ 56/100 ____
# Not Recomputed!
# Affected correctors: 228.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 228.0
# _____Sample__ 57/100 ____
# Not Recomputed!
# Affected correctors: 214.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 214.0
# _____Sample__ 58/100 ____
# Not Recomputed!
# Affected correctors: 207.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 207.0
# _____Sample__ 59/100 ____
# Not Recomputed!
# Affected correctors: 219.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 219.0
# _____Sample__ 60/100 ____
# Not Recomputed!
# Affected correctors: 247.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 247.0
# _____Sample__ 61/100 ____
# Not Recomputed!
# Affected correctors: 217.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 217.0
# _____Sample__ 62/100 ____
# Not Recomputed!
# Affected correctors: 229.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 229.0
# _____Sample__ 63/100 ____
# Not Recomputed!
# Affected correctors: 245.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 245.0
# _____Sample__ 64/100 ____
# Not Recomputed!
# Affected correctors: 254.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 254.0
# _____Sample__ 65/100 ____
# Not Recomputed!
# Affected correctors: 227.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 227.0
# _____Sample__ 66/100 ____
# Not Recomputed!
# Affected correctors: 242.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 242.0
# _____Sample__ 67/100 ____
# Not Recomputed!
# Affected correctors: 248.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 248.0
# _____Sample__ 68/100 ____
# Not Recomputed!
# Affected correctors: 256.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 256.0
# _____Sample__ 69/100 ____
# Not Recomputed!
# Affected correctors: 198.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 198.0
# _____Sample__ 70/100 ____
# Not Recomputed!
# Affected correctors: 208.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 208.0
# _____Sample__ 71/100 ____
# Not Recomputed!
# Affected correctors: 236.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 236.0
# _____Sample__ 72/100 ____
# Not Recomputed!
# Affected correctors: 218.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 218.0
# _____Sample__ 73/100 ____
# Not Recomputed!
# Affected correctors: 223.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 223.0
# _____Sample__ 74/100 ____
# Not Recomputed!
# Affected correctors: 256.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 256.0
# _____Sample__ 75/100 ____
# Not Recomputed!
# Affected correctors: 232.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 232.0
# _____Sample__ 76/100 ____
# Not Recomputed!
# Affected correctors: 256.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 256.0
# _____Sample__ 77/100 ____
# Not Recomputed!
# Affected correctors: 217.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 217.0
# _____Sample__ 78/100 ____
# Not Recomputed!
# Affected correctors: 256.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 256.0
# _____Sample__ 79/100 ____
# Not Recomputed!
# Affected correctors: 254.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 254.0
# _____Sample__ 80/100 ____
# Not Recomputed!
# Affected correctors: 201.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 201.0
# _____Sample__ 81/100 ____
# Not Recomputed!
# Affected correctors: 224.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 224.0
# _____Sample__ 82/100 ____
# Not Recomputed!
# Affected correctors: 244.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 244.0
# _____Sample__ 83/100 ____
# Not Recomputed!
# Affected correctors: 207.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 207.0
# _____Sample__ 84/100 ____
# Not Recomputed!
# Affected correctors: 252.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 252.0
# _____Sample__ 85/100 ____
# Not Recomputed!
# Affected correctors: 246.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 246.0
# _____Sample__ 86/100 ____
# Not Recomputed!
# Affected correctors: 196.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 196.0
# _____Sample__ 87/100 ____
# Not Recomputed!
# Affected correctors: 256.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 256.0
# _____Sample__ 88/100 ____
# Not Recomputed!
# Affected correctors: 224.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 224.0
# _____Sample__ 89/100 ____
# Not Recomputed!
# Affected correctors: 252.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 252.0
# _____Sample__ 90/100 ____
# Not Recomputed!
# Affected correctors: 244.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 244.0
# _____Sample__ 91/100 ____
# Not Recomputed!
# Affected correctors: 256.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 256.0
# _____Sample__ 92/100 ____
# Not Recomputed!
# Affected correctors: 217.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 217.0
# _____Sample__ 93/100 ____
# Not Recomputed!
# Affected correctors: 256.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 256.0
# _____Sample__ 94/100 ____
# Not Recomputed!
# Affected correctors: 252.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 252.0
# _____Sample__ 95/100 ____
# Not Recomputed!
# Affected correctors: 191.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 191.0
# _____Sample__ 96/100 ____
# Not Recomputed!
# Affected correctors: 233.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 233.0
# _____Sample__ 97/100 ____
# Not Recomputed!
# Affected correctors: 256.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 77.0
# p = 100% Updated correctors: 256.0
# _____Sample__ 98/100 ____
# Not Recomputed!
# Affected correctors: 217.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 13.0
# p = 10% Updated correctors: 26.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 217.0
# _____Sample__ 99/100 ____
# Not Recomputed!
# Affected correctors: 252.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 52.0
# p = 30% Updated correctors: 78.0
# p = 100% Updated correctors: 252.0
# _____Sample__ 100/100 ____
# Not Recomputed!
# Affected correctors: 137.0
# p = 0% Updated correctors: 0.0
# p = 5% Updated correctors: 14.0
# p = 10% Updated correctors: 27.0
# p = 20% Updated correctors: 53.0
# p = 30% Updated correctors: 79.0
# p = 100% Updated correctors: 137.0
