# %% [markdown]
# # Monte Carlo simulation Coefficient 3

# %%
import os
import sys
import numpy as np
import scipy.sparse as sparse
import scipy.stats as stats
import random
import csv

# %matplotlib notebook
import matplotlib.pyplot as plt
from visualize import drawCoefficient
from data import * 

from gridlod import interp, coef, util, fem, world, linalg, femsolver
import pg_rand, femsolverCoarse, buildcoef2d
from gridlod.world import World

# %% [markdown]
# ## Result function

# %%
def result(pglod, world, CoefClass, A, f, MC=1, numberofcorrectors=20, MCplot=None, ROOT=None):
    NWorldFine = world.NWorldFine
    NWorldCoarse = world.NWorldCoarse
    NCoarseElement = world.NCoarseElement
    
    boundaryConditions = world.boundaryConditions
    NpFine = np.prod(NWorldFine+1)
    NpCoarse = np.prod(NWorldCoarse+1)
    
    #### initial #####
    xmLoda = []
    xmVcLoda = []
    xmLodVcLoda = []
    
    ems = []
    
    plottingx = []
    plottingy = []
    plottingz = []
    
    plotting2x = []
    plotting2y = []
    plotting2z = []
    
    plotting3x = []
    plotting3y = []
    plotting3z = []
    
    for i in range(0,MC):
        print '_____Sample__ ' + str(i+1) + '/' + str(MC) + ' ____' 
        xmLod, xmVcLod, xmLodVcLod = VcLod(pglod, world, CoefClass, f, prob=100, numberofcorrectors=numberofcorrectors, m=i)
        xmLoda.append(xmLod)
        xmVcLoda.append(xmVcLod)
        xmLodVcLoda.append(xmLodVcLod)
    
        muLod = 0
        muVcLod = 0
        muLodVcLod = 0
        if i == 0:
            continue
            
        for j in range(0,i+1):
            muLod += xmLoda[j]
            muVcLod += xmVcLoda[j]
            muLodVcLod += xmLodVcLoda[j]
    
        muLod /= i+1
        muVcLod /= i+1
        muLodVcLod /= i+1
    
        sig2Lod = 0
        sig2VcLod = 0
        sig2LodVcLod = 0
    
        for j in range(0,i+1):
            sig2Lod += (xmLoda[j]-muLod)**(2)
            sig2VcLod += (xmVcLoda[j]-muVcLod)**(2)
            sig2LodVcLod += (xmLodVcLoda[j]-muLodVcLod)**(2)
        
        sig2Lod /= i
        sig2VcLod /= i
        sig2LodVcLod /= i
    
        a = [np.sqrt(sig2Lod)/np.sqrt(i+1)*1.96,np.sqrt(sig2VcLod)/np.sqrt(i+1)*1.96,np.sqrt(sig2LodVcLod)/np.sqrt(i+1)*1.96]
        mum = [muLod,muVcLod,muLodVcLod]
        
        plottingx.append(mum[0]-a[0])
        plottingy.append(mum[0])
        plottingz.append(mum[0]+a[0])
        
        plotting2x.append(mum[1]-a[1])
        plotting2y.append(mum[1])
        plotting2z.append(mum[1]+a[1])

        plotting3x.append(mum[1]-a[1])
        plotting3y.append(mum[1])
        plotting3z.append(mum[1]+a[1])
        
        ems.append(i+1)
        Matrix = CoefClass.Matrix.flatten()
        safer(ROOT, mum, a, plottingx, plottingy, plottingz, plotting2x, plotting2y, plotting2z, plotting3x, plotting3y, plotting3z, ems, Matrix)
        
    return a,mum

# %% [markdown]
# ## Error function

# %%
def Errors(world, R, uLod, uVcLod):
    NWorldFine = world.NWorldFine
    NpFine = np.prod(NWorldFine+1)
    
    ANew = R.flatten()
    boundaryConditions = world.boundaryConditions
    f_fine = np.ones(NpFine)
    uFineFem, AFine, MFine = femsolver.solveFine(world, ANew, f_fine, None, boundaryConditions)
    
    errorLod = np.sqrt(np.dot(uFineFem - uLod, MFine*(uFineFem - uLod))) / np.sqrt(np.dot(uFineFem, MFine*uFineFem))
    errorVcLod = np.sqrt(np.dot(uFineFem - uVcLod, MFine*(uFineFem - uVcLod))) / np.sqrt(np.dot(uFineFem, MFine*uFineFem))
    errorLodVcLod = np.sqrt(np.dot(uVcLod - uLod, MFine*(uVcLod - uLod))) / np.sqrt(np.dot(uLod, MFine*uLod))
    
    return errorLod, errorVcLod, errorLodVcLod

# %% [markdown]
# ## VC-LOD

# %%
def VcLod(pglod, world, CoefClass,f, prob=100, numberofcorrectors=20, m=0):
    NWorldFine = world.NWorldFine
    NWorldCoarse = world.NWorldCoarse
    NCoarseElement = world.NCoarseElement

    boundaryConditions = world.boundaryConditions
    NpFine = np.prod(NWorldFine+1)
    NpCoarse = np.prod(NWorldCoarse+1)

    R = CoefClass.RandomVanish( probfactor      = prob,
                                PartlyVanish    = None,
                                Original        = True)

    #new Coefficient
    ANew = R.flatten()
    Anew = coef.coefficientFine(NWorldCoarse, NCoarseElement, ANew)

    ###### tolerance = 0 ######
    vis, eps = pglod.updateCorrectors(Anew, 0, f, 1, clearFineQuantities=False, mc=True)
    print 'Affected correctors: ' + str(np.sum(vis))
    KFull = pglod.assembleMsStiffnessMatrix()
    MFull = fem.assemblePatchMatrix(NWorldCoarse, world.MLocCoarse)
    free  = util.interiorpIndexMap(NWorldCoarse)

    bFull = MFull*f
    KFree = KFull[free][:,free]
    bFree = bFull[free]

    xFree = sparse.linalg.spsolve(KFree, bFree)
    basis = fem.assembleProlongationMatrix(NWorldCoarse, NCoarseElement)

    basisCorrectors = pglod.assembleBasisCorrectors()
    modifiedBasis = basis - basisCorrectors

    xFull = np.zeros(NpCoarse)
    xFull[free] = xFree
    uCoarse = xFull
    uLod = modifiedBasis*xFull

    ##### tolerance = certain ######
    eps = filter(lambda x: x!=0, eps)
    eps.sort()
    epssize = np.size(eps)
    until = int(round(numberofcorrectors/100. * epssize,0))
    if epssize != 0:
        until = int(round(until * 256./epssize,0))
    tolrev = []
    for i in range(epssize-1,-1,-1):
        tolrev.append(eps[i])
    
    if epssize == 0:
        print 'nothing to update'
        xmLod, xmVcLod, xmLodVcLod = Errors(world, R, uLod, uLod)
    
    else:
        if until >= epssize:
            until = epssize-1
        tol = tolrev[until]
    
        vistol = pglod.updateCorrectors(Anew, tol, f, clearFineQuantities=False)
        print 'Updated correctors: ' + str(np.sum(vistol))
        KFull = pglod.assembleMsStiffnessMatrix()
        MFull = fem.assemblePatchMatrix(NWorldCoarse, world.MLocCoarse)
        free  = util.interiorpIndexMap(NWorldCoarse)

        bFull = MFull*f
        KFree = KFull[free][:,free]
        bFree = bFull[free]

        xFree = sparse.linalg.spsolve(KFree, bFree)
        basis = fem.assembleProlongationMatrix(NWorldCoarse, NCoarseElement)

        basisCorrectors = pglod.assembleBasisCorrectors()
        modifiedBasis = basis - basisCorrectors

        xFull = np.zeros(NpCoarse)
        xFull[free] = xFree
        uCoarse = xFull
        uVcLod = modifiedBasis*xFull

        xmLod, xmVcLod, xmLodVcLod = Errors(world, R, uLod, uVcLod)

    return xmLod, xmVcLod, xmLodVcLod

# %%
#background
bg = 0.05
#values
val = 1
random.seed(20)
#fine World
NWorldFine = np.array([256, 256])
NpFine = np.prod(NWorldFine+1)                                                                               

#coarse World
NWorldCoarse = np.array([16,16])
NpCoarse = np.prod(NWorldCoarse+1)

#ratio between Fine and Coarse
NCoarseElement = NWorldFine/NWorldCoarse

boundaryConditions = np.array([[0, 0],
                               [0, 0]])

world = World(NWorldCoarse, NCoarseElement, boundaryConditions)

#righthandside
f = np.ones(NpCoarse)

#coefficient 3
CoefClass = buildcoef2d.Coefficient2d(NWorldFine, 
                        bg                  = bg, 
                        val                 = val, 
                        length              = 8, 
                        thick               = 2, 
                        space               = 4, 
                        probfactor          = 1, 
                        right               = 0, 
                        down                = 0, 
                        diagr1              = 0, 
                        diagr2              = 0, 
                        diagl1              = 0, 
                        diagl2              = 1, 
                        LenSwitch           = None, 
                        thickSwitch         = None, 
                        equidistant         = None, 
                        ChannelHorizontal   = None, 
                        ChannelVertical     = None,
                        BoundarySpace       = True)

A = CoefClass.BuildCoefficient()
ABase = A.flatten()
        
plt.figure("OriginalCoefficient")
drawCoefficient(NWorldFine, ABase)
plt.title('Original coefficient')

k = 4

###### precompute #######
NWorldFine = world.NWorldFine
NWorldCoarse = world.NWorldCoarse
NCoarseElement = world.NCoarseElement

boundaryConditions = world.boundaryConditions
NpFine = np.prod(NWorldFine+1)
NpCoarse = np.prod(NWorldCoarse+1)

#interpolant
IPatchGenerator = lambda i, N: interp.L2ProjectionPatchMatrix(i, N, NWorldCoarse, NCoarseElement, boundaryConditions)

#old Coefficient (need flatten form)
ABase = A.flatten()
Aold = coef.coefficientFine(NWorldCoarse, NCoarseElement, ABase)

pglod = pg_rand.VcPetrovGalerkinLOD(Aold, world, k, IPatchGenerator, 0)
pglod.originCorrectors(clearFineQuantities=False)

#correctors that we will update in %
numberofcorrectors = 10

MC = 400
ROOT = '../test_data/MonteCarlo/Coef3/p20'
a, mum = result(pglod, world, CoefClass, A, f, MC, numberofcorrectors, MCplot=True, ROOT=ROOT)

print 'p = '+ str(10) + '%'
print 'uLod  ' + str(mum[0]) + ' +- ' + str(a[0])
print 'uVcLod ' + str(mum[1]) + ' +- ' + str(a[1])
print 'uLodVcLod ' + str(mum[2]) + ' +- ' + str(a[2])
# Out:
# <div id='6b671750-037c-4bc2-b868-9e8ecec0a461'></div>
# _____Sample__ 1/400 ____
# Affected correctors: 227.0
# Updated correctors: 26.0
# _____Sample__ 2/400 ____
# Affected correctors: 187.0
# Updated correctors: 26.0
# _____Sample__ 3/400 ____
# Affected correctors: 213.0
# Updated correctors: 25.0
# _____Sample__ 4/400 ____
# Affected correctors: 251.0
# Updated correctors: 25.0
# _____Sample__ 5/400 ____
# Affected correctors: 180.0
# Updated correctors: 26.0
# _____Sample__ 6/400 ____
# Affected correctors: 199.0
# Updated correctors: 26.0
# _____Sample__ 7/400 ____
# Affected correctors: 158.0
# Updated correctors: 26.0
# _____Sample__ 8/400 ____
# Affected correctors: 161.0
# Updated correctors: 25.0
# _____Sample__ 9/400 ____
# Affected correctors: 171.0
# Updated correctors: 25.0
# _____Sample__ 10/400 ____
# Affected correctors: 218.0
# Updated correctors: 26.0
# _____Sample__ 11/400 ____
# Affected correctors: 240.0
# Updated correctors: 26.0
# _____Sample__ 12/400 ____
# Affected correctors: 152.0
# Updated correctors: 25.0
# _____Sample__ 13/400 ____
# Affected correctors: 157.0
# Updated correctors: 26.0
# _____Sample__ 14/400 ____
# Affected correctors: 208.0
# Updated correctors: 26.0
# _____Sample__ 15/400 ____
# Affected correctors: 139.0
# Updated correctors: 26.0
# _____Sample__ 16/400 ____
# Affected correctors: 205.0
# Updated correctors: 26.0
# _____Sample__ 17/400 ____
# Affected correctors: 238.0
# Updated correctors: 26.0
# _____Sample__ 18/400 ____
# Affected correctors: 245.0
# Updated correctors: 26.0
# _____Sample__ 19/400 ____
# Affected correctors: 183.0
# Updated correctors: 25.0
# _____Sample__ 20/400 ____
# Affected correctors: 238.0
# Updated correctors: 26.0
# _____Sample__ 21/400 ____
# Affected correctors: 150.0
# Updated correctors: 26.0
# _____Sample__ 22/400 ____
# Affected correctors: 254.0
# Updated correctors: 25.0
# _____Sample__ 23/400 ____
# Affected correctors: 200.0
# Updated correctors: 26.0
# _____Sample__ 24/400 ____
# Affected correctors: 172.0
# Updated correctors: 25.0
# _____Sample__ 25/400 ____
# Affected correctors: 102.0
# Updated correctors: 25.0
# _____Sample__ 26/400 ____
# Affected correctors: 162.0
# Updated correctors: 25.0
# _____Sample__ 27/400 ____
# Affected correctors: 184.0
# Updated correctors: 25.0
# _____Sample__ 28/400 ____
# Affected correctors: 224.0
# Updated correctors: 25.0
# _____Sample__ 29/400 ____
# Affected correctors: 180.0
# Updated correctors: 26.0
# _____Sample__ 30/400 ____
# Affected correctors: 244.0
# Updated correctors: 25.0
# _____Sample__ 31/400 ____
# Affected correctors: 141.0
# Updated correctors: 25.0
# _____Sample__ 32/400 ____
# Affected correctors: 196.0
# Updated correctors: 26.0
# _____Sample__ 33/400 ____
# Affected correctors: 144.0
# Updated correctors: 25.0
# _____Sample__ 34/400 ____
# Affected correctors: 205.0
# Updated correctors: 26.0
# _____Sample__ 35/400 ____
# Affected correctors: 223.0
# Updated correctors: 25.0
# _____Sample__ 36/400 ____
# Affected correctors: 192.0
# Updated correctors: 25.0
# _____Sample__ 37/400 ____
# Affected correctors: 147.0
# Updated correctors: 26.0
# _____Sample__ 38/400 ____
# Affected correctors: 162.0
# Updated correctors: 25.0
# _____Sample__ 39/400 ____
# Affected correctors: 205.0
# Updated correctors: 26.0
# _____Sample__ 40/400 ____
# Affected correctors: 245.0
# Updated correctors: 26.0
# _____Sample__ 41/400 ____
# Affected correctors: 224.0
# Updated correctors: 25.0
# _____Sample__ 42/400 ____
# Affected correctors: 186.0
# Updated correctors: 26.0
# _____Sample__ 43/400 ____
# Affected correctors: 152.0
# Updated correctors: 25.0
# _____Sample__ 44/400 ____
# Affected correctors: 180.0
# Updated correctors: 26.0
# _____Sample__ 45/400 ____
# Affected correctors: 202.0
# Updated correctors: 25.0
# _____Sample__ 46/400 ____
# Affected correctors: 184.0
# Updated correctors: 25.0
# _____Sample__ 47/400 ____
# Affected correctors: 150.0
# Updated correctors: 26.0
# _____Sample__ 48/400 ____
# Affected correctors: 225.0
# Updated correctors: 26.0
# _____Sample__ 49/400 ____
# Affected correctors: 214.0
# Updated correctors: 25.0
# _____Sample__ 50/400 ____
# Affected correctors: 231.0
# Updated correctors: 25.0
# _____Sample__ 51/400 ____
# Affected correctors: 199.0
# Updated correctors: 26.0
# _____Sample__ 52/400 ____
# Affected correctors: 185.0
# Updated correctors: 26.0
# _____Sample__ 53/400 ____
# Affected correctors: 111.0
# Updated correctors: 25.0
# _____Sample__ 54/400 ____
# Affected correctors: 104.0
# Updated correctors: 25.0
# _____Sample__ 55/400 ____
# Affected correctors: 236.0
# Updated correctors: 26.0
# _____Sample__ 56/400 ____
# Affected correctors: 188.0
# Updated correctors: 26.0
# _____Sample__ 57/400 ____
# Affected correctors: 180.0
# Updated correctors: 26.0
# _____Sample__ 58/400 ____
# Affected correctors: 222.0
# Updated correctors: 25.0
# _____Sample__ 59/400 ____
# Affected correctors: 175.0
# Updated correctors: 26.0
# _____Sample__ 60/400 ____
# Affected correctors: 167.0
# Updated correctors: 26.0
# _____Sample__ 61/400 ____
# Affected correctors: 177.0
# Updated correctors: 26.0
# _____Sample__ 62/400 ____
# Affected correctors: 210.0
# Updated correctors: 26.0
# _____Sample__ 63/400 ____
# Affected correctors: 215.0
# Updated correctors: 26.0
# _____Sample__ 64/400 ____
# Affected correctors: 182.0
# Updated correctors: 25.0
# _____Sample__ 65/400 ____
# Affected correctors: 180.0
# Updated correctors: 26.0
# _____Sample__ 66/400 ____
# Affected correctors: 149.0
# Updated correctors: 26.0
# _____Sample__ 67/400 ____
# Affected correctors: 218.0
# Updated correctors: 26.0
# _____Sample__ 68/400 ____
# Affected correctors: 235.0
# Updated correctors: 26.0
# _____Sample__ 69/400 ____
# Affected correctors: 238.0
# Updated correctors: 26.0
# _____Sample__ 70/400 ____
# Affected correctors: 191.0
# Updated correctors: 25.0
# _____Sample__ 71/400 ____
# Affected correctors: 206.0
# Updated correctors: 26.0
# _____Sample__ 72/400 ____
# Affected correctors: 225.0
# Updated correctors: 26.0
# _____Sample__ 73/400 ____
# Affected correctors: 248.0
# Updated correctors: 26.0
# _____Sample__ 74/400 ____
# Affected correctors: 108.0
# Updated correctors: 26.0
# _____Sample__ 75/400 ____
# Affected correctors: 214.0
# Updated correctors: 25.0
# _____Sample__ 76/400 ____
# Affected correctors: 210.0
# Updated correctors: 26.0
# _____Sample__ 77/400 ____
# Affected correctors: 247.0
# Updated correctors: 26.0
# _____Sample__ 78/400 ____
# Affected correctors: 248.0
# Updated correctors: 26.0
# _____Sample__ 79/400 ____
# Affected correctors: 192.0
# Updated correctors: 25.0
# _____Sample__ 80/400 ____
# Affected correctors: 163.0
# Updated correctors: 25.0
# _____Sample__ 81/400 ____
# Affected correctors: 49.0
# Updated correctors: 26.0
# _____Sample__ 82/400 ____
# Affected correctors: 235.0
# Updated correctors: 26.0
# _____Sample__ 83/400 ____
# Affected correctors: 129.0
# Updated correctors: 26.0
# _____Sample__ 84/400 ____
# Affected correctors: 220.0
# Updated correctors: 26.0
# _____Sample__ 85/400 ____
# Affected correctors: 256.0
# Updated correctors: 26.0
# _____Sample__ 86/400 ____
# Affected correctors: 248.0
# Updated correctors: 26.0
# _____Sample__ 87/400 ____
# Affected correctors: 110.0
# Updated correctors: 26.0
# _____Sample__ 88/400 ____
# Affected correctors: 201.0
# Updated correctors: 25.0
# _____Sample__ 89/400 ____
# Affected correctors: 148.0
# Updated correctors: 26.0
# _____Sample__ 90/400 ____
# Affected correctors: 202.0
# Updated correctors: 25.0
# _____Sample__ 91/400 ____
# Affected correctors: 226.0
# Updated correctors: 26.0
# _____Sample__ 92/400 ____
# Affected correctors: 164.0
# Updated correctors: 25.0
# _____Sample__ 93/400 ____
# Affected correctors: 251.0
# Updated correctors: 25.0
# _____Sample__ 94/400 ____
# Affected correctors: 88.0
# Updated correctors: 26.0
# _____Sample__ 95/400 ____
# Affected correctors: 112.0
# Updated correctors: 25.0
# _____Sample__ 96/400 ____
# Affected correctors: 212.0
# Updated correctors: 25.0
# _____Sample__ 97/400 ____
# Affected correctors: 165.0
# Updated correctors: 26.0
# _____Sample__ 98/400 ____
# Affected correctors: 45.0
# Updated correctors: 28.0
# _____Sample__ 99/400 ____
# Affected correctors: 166.0
# Updated correctors: 26.0
# _____Sample__ 100/400 ____
# Affected correctors: 48.0
# Updated correctors: 27.0
# _____Sample__ 101/400 ____
# Affected correctors: 225.0
# Updated correctors: 26.0
# _____Sample__ 102/400 ____
# Affected correctors: 224.0
# Updated correctors: 25.0
# _____Sample__ 103/400 ____
# Affected correctors: 190.0
# Updated correctors: 26.0
# _____Sample__ 104/400 ____
# Affected correctors: 166.0
# Updated correctors: 26.0
# _____Sample__ 105/400 ____
# Affected correctors: 208.0
# Updated correctors: 26.0
# _____Sample__ 106/400 ____
# Affected correctors: 172.0
# Updated correctors: 25.0
# _____Sample__ 107/400 ____
# Affected correctors: 247.0
# Updated correctors: 26.0
# _____Sample__ 108/400 ____
# Affected correctors: 156.0
# Updated correctors: 26.0
# _____Sample__ 109/400 ____
# Affected correctors: 187.0
# Updated correctors: 26.0
# _____Sample__ 110/400 ____
# Affected correctors: 206.0
# Updated correctors: 26.0
# _____Sample__ 111/400 ____
# Affected correctors: 141.0
# Updated correctors: 25.0
# _____Sample__ 112/400 ____
# Affected correctors: 184.0
# Updated correctors: 25.0
# _____Sample__ 113/400 ____
# Affected correctors: 208.0
# Updated correctors: 26.0
# _____Sample__ 114/400 ____
# Affected correctors: 254.0
# Updated correctors: 25.0
# _____Sample__ 115/400 ____
# Affected correctors: 188.0
# Updated correctors: 26.0
# _____Sample__ 116/400 ____
# Affected correctors: 247.0
# Updated correctors: 26.0
# _____Sample__ 117/400 ____
# Affected correctors: 202.0
# Updated correctors: 25.0
# _____Sample__ 118/400 ____
# Affected correctors: 222.0
# Updated correctors: 25.0
# _____Sample__ 119/400 ____
# Affected correctors: 131.0
# Updated correctors: 25.0
# _____Sample__ 120/400 ____
# Affected correctors: 186.0
# Updated correctors: 26.0
# _____Sample__ 121/400 ____
# Affected correctors: 182.0
# Updated correctors: 25.0
# _____Sample__ 122/400 ____
# Affected correctors: 227.0
# Updated correctors: 26.0
# _____Sample__ 123/400 ____
# Affected correctors: 210.0
# Updated correctors: 26.0
# _____Sample__ 124/400 ____
# Affected correctors: 121.0
# Updated correctors: 25.0
# _____Sample__ 125/400 ____
# Affected correctors: 166.0
# Updated correctors: 26.0
# _____Sample__ 126/400 ____
# Affected correctors: 208.0
# Updated correctors: 26.0
# _____Sample__ 127/400 ____
# Affected correctors: 183.0
# Updated correctors: 25.0
# _____Sample__ 128/400 ____
# Affected correctors: 233.0
# Updated correctors: 25.0
# _____Sample__ 129/400 ____
# Affected correctors: 168.0
# Updated correctors: 26.0
# _____Sample__ 130/400 ____
# Affected correctors: 129.0
# Updated correctors: 26.0
# _____Sample__ 131/400 ____
# Affected correctors: 188.0
# Updated correctors: 26.0
# _____Sample__ 132/400 ____
# Affected correctors: 244.0
# Updated correctors: 25.0
# _____Sample__ 133/400 ____
# Affected correctors: 199.0
# Updated correctors: 26.0
# _____Sample__ 134/400 ____
# Affected correctors: 215.0
# Updated correctors: 26.0
# _____Sample__ 135/400 ____
# Affected correctors: 196.0
# Updated correctors: 26.0
# _____Sample__ 136/400 ____
# Affected correctors: 194.0
# Updated correctors: 25.0
# _____Sample__ 137/400 ____
# Affected correctors: 220.0
# Updated correctors: 26.0
# _____Sample__ 138/400 ____
# Affected correctors: 133.0
# Updated correctors: 25.0
# _____Sample__ 139/400 ____
# Affected correctors: 192.0
# Updated correctors: 25.0
# _____Sample__ 140/400 ____
# Affected correctors: 256.0
# Updated correctors: 26.0
# _____Sample__ 141/400 ____
# Affected correctors: 97.0
# Updated correctors: 26.0
# _____Sample__ 142/400 ____
# Affected correctors: 158.0
# Updated correctors: 26.0
# _____Sample__ 143/400 ____
# Affected correctors: 195.0
# Updated correctors: 26.0
# _____Sample__ 144/400 ____
# Affected correctors: 175.0
# Updated correctors: 26.0
# _____Sample__ 145/400 ____
# Affected correctors: 123.0
# Updated correctors: 25.0
# _____Sample__ 146/400 ____
# Affected correctors: 205.0
# Updated correctors: 26.0
# _____Sample__ 147/400 ____
# Affected correctors: 108.0
# Updated correctors: 26.0
# _____Sample__ 148/400 ____
# Affected correctors: 142.0
# Updated correctors: 25.0
# _____Sample__ 149/400 ____
# Affected correctors: 203.0
# Updated correctors: 25.0
# _____Sample__ 150/400 ____
# Affected correctors: 237.0
# Updated correctors: 26.0
# _____Sample__ 151/400 ____
# Affected correctors: 184.0
# Updated correctors: 25.0
# _____Sample__ 152/400 ____
# Affected correctors: 225.0
# Updated correctors: 26.0
# _____Sample__ 153/400 ____
# Affected correctors: 187.0
# Updated correctors: 26.0
# _____Sample__ 154/400 ____
# Affected correctors: 48.0
# Updated correctors: 27.0
# _____Sample__ 155/400 ____
# Affected correctors: 224.0
# Updated correctors: 25.0
# _____Sample__ 156/400 ____
# Affected correctors: 216.0
# Updated correctors: 26.0
# _____Sample__ 157/400 ____
# Affected correctors: 141.0
# Updated correctors: 25.0
# _____Sample__ 158/400 ____
# Affected correctors: 150.0
# Updated correctors: 26.0
# _____Sample__ 159/400 ____
# Affected correctors: 217.0
# Updated correctors: 26.0
# _____Sample__ 160/400 ____
# Affected correctors: 237.0
# Updated correctors: 26.0
# _____Sample__ 161/400 ____
# Affected correctors: 160.0
# Updated correctors: 26.0
# _____Sample__ 162/400 ____
# Affected correctors: 177.0
# Updated correctors: 26.0
# _____Sample__ 163/400 ____
# Affected correctors: 202.0
# Updated correctors: 25.0
# _____Sample__ 164/400 ____
# Affected correctors: 225.0
# Updated correctors: 26.0
# _____Sample__ 165/400 ____
# Affected correctors: 163.0
# Updated correctors: 25.0
# _____Sample__ 166/400 ____
# Affected correctors: 223.0
# Updated correctors: 25.0
# _____Sample__ 167/400 ____
# Affected correctors: 209.0
# Updated correctors: 26.0
# _____Sample__ 168/400 ____
# Affected correctors: 247.0
# Updated correctors: 26.0
# _____Sample__ 169/400 ____
# Affected correctors: 175.0
# Updated correctors: 26.0
# _____Sample__ 170/400 ____
# Affected correctors: 200.0
# Updated correctors: 26.0
# _____Sample__ 171/400 ____
# Affected correctors: 150.0
# Updated correctors: 26.0
# _____Sample__ 172/400 ____
# Affected correctors: 190.0
# Updated correctors: 26.0
# _____Sample__ 173/400 ____
# Affected correctors: 184.0
# Updated correctors: 25.0
# _____Sample__ 174/400 ____
# Affected correctors: 234.0
# Updated correctors: 25.0
# _____Sample__ 175/400 ____
# Affected correctors: 153.0
# Updated correctors: 25.0
# _____Sample__ 176/400 ____
# Affected correctors: 240.0
# Updated correctors: 26.0
# _____Sample__ 177/400 ____
# Affected correctors: 153.0
# Updated correctors: 25.0
# _____Sample__ 178/400 ____
# Affected correctors: 248.0
# Updated correctors: 26.0
# _____Sample__ 179/400 ____
# Affected correctors: 191.0
# Updated correctors: 25.0
# _____Sample__ 180/400 ____
# Affected correctors: 36.0
# Updated correctors: 28.0
# _____Sample__ 181/400 ____
# Affected correctors: 130.0
# Updated correctors: 26.0
# _____Sample__ 182/400 ____
# Affected correctors: 170.0
# Updated correctors: 26.0
# _____Sample__ 183/400 ____
# Affected correctors: 132.0
# Updated correctors: 25.0
# _____Sample__ 184/400 ____
# Affected correctors: 229.0
# Updated correctors: 26.0
# _____Sample__ 185/400 ____
# Affected correctors: 168.0
# Updated correctors: 26.0
# _____Sample__ 186/400 ____
# Affected correctors: 45.0
# Updated correctors: 28.0
# _____Sample__ 187/400 ____
# Affected correctors: 153.0
# Updated correctors: 25.0
# _____Sample__ 188/400 ____
# Affected correctors: 202.0
# Updated correctors: 25.0
# _____Sample__ 189/400 ____
# Affected correctors: 214.0
# Updated correctors: 25.0
# _____Sample__ 190/400 ____
# Affected correctors: 103.0
# Updated correctors: 25.0
# _____Sample__ 191/400 ____
# Affected correctors: 221.0
# Updated correctors: 25.0
# _____Sample__ 192/400 ____
# Affected correctors: 114.0
# Updated correctors: 25.0
# _____Sample__ 193/400 ____
# Affected correctors: 255.0
# Updated correctors: 26.0
# _____Sample__ 194/400 ____
# Affected correctors: 182.0
# Updated correctors: 25.0
# _____Sample__ 195/400 ____
# Affected correctors: 147.0
# Updated correctors: 26.0
# _____Sample__ 196/400 ____
# Affected correctors: 186.0
# Updated correctors: 26.0
# _____Sample__ 197/400 ____
# Affected correctors: 211.0
# Updated correctors: 25.0
# _____Sample__ 198/400 ____
# Affected correctors: 177.0
# Updated correctors: 26.0
# _____Sample__ 199/400 ____
# Affected correctors: 231.0
# Updated correctors: 25.0
# _____Sample__ 200/400 ____
# Affected correctors: 120.0
# Updated correctors: 26.0
# _____Sample__ 201/400 ____
# Affected correctors: 208.0
# Updated correctors: 26.0
# _____Sample__ 202/400 ____
# Affected correctors: 176.0
# Updated correctors: 26.0
# _____Sample__ 203/400 ____
# Affected correctors: 248.0
# Updated correctors: 26.0
# _____Sample__ 204/400 ____
# Affected correctors: 163.0
# Updated correctors: 25.0
# _____Sample__ 205/400 ____
# Affected correctors: 181.0
# Updated correctors: 25.0
# _____Sample__ 206/400 ____
# Affected correctors: 152.0
# Updated correctors: 25.0
# _____Sample__ 207/400 ____
# Affected correctors: 247.0
# Updated correctors: 26.0
# _____Sample__ 208/400 ____
# Affected correctors: 190.0
# Updated correctors: 26.0
# _____Sample__ 209/400 ____
# Affected correctors: 208.0
# Updated correctors: 26.0
# _____Sample__ 210/400 ____
# Affected correctors: 181.0
# Updated correctors: 25.0
# _____Sample__ 211/400 ____
# Affected correctors: 241.0
# Updated correctors: 25.0
# _____Sample__ 212/400 ____
# Affected correctors: 199.0
# Updated correctors: 26.0
# _____Sample__ 213/400 ____
# Affected correctors: 201.0
# Updated correctors: 25.0
# _____Sample__ 214/400 ____
# Affected correctors: 219.0
# Updated correctors: 26.0
# _____Sample__ 215/400 ____
# Affected correctors: 149.0
# Updated correctors: 26.0
# _____Sample__ 216/400 ____
# Affected correctors: 164.0
# Updated correctors: 25.0
# _____Sample__ 217/400 ____
# Affected correctors: 227.0
# Updated correctors: 26.0
# _____Sample__ 218/400 ____
# Affected correctors: 134.0
# Updated correctors: 25.0
# _____Sample__ 219/400 ____
# Affected correctors: 225.0
# Updated correctors: 26.0
# _____Sample__ 220/400 ____
# Affected correctors: 182.0
# Updated correctors: 25.0
# _____Sample__ 221/400 ____
# Affected correctors: 206.0
# Updated correctors: 26.0
# _____Sample__ 222/400 ____
# Affected correctors: 193.0
# Updated correctors: 25.0
# _____Sample__ 223/400 ____
# Affected correctors: 175.0
# Updated correctors: 26.0
# _____Sample__ 224/400 ____
# Affected correctors: 234.0
# Updated correctors: 25.0
# _____Sample__ 225/400 ____
# Affected correctors: 224.0
# Updated correctors: 25.0
# _____Sample__ 226/400 ____
# Affected correctors: 178.0
# Updated correctors: 26.0
# _____Sample__ 227/400 ____
# Affected correctors: 216.0
# Updated correctors: 26.0
# _____Sample__ 228/400 ____
# Affected correctors: 216.0
# Updated correctors: 26.0
# _____Sample__ 229/400 ____
# Affected correctors: 217.0
# Updated correctors: 26.0
# _____Sample__ 230/400 ____
# Affected correctors: 215.0
# Updated correctors: 26.0
# _____Sample__ 231/400 ____
# Affected correctors: 192.0
# Updated correctors: 25.0
# _____Sample__ 232/400 ____
# Affected correctors: 75.0
# Updated correctors: 27.0
# _____Sample__ 233/400 ____
# Affected correctors: 160.0
# Updated correctors: 26.0
# _____Sample__ 234/400 ____
# Affected correctors: 161.0
# Updated correctors: 25.0
# _____Sample__ 235/400 ____
# Affected correctors: 189.0
# Updated correctors: 26.0
# _____Sample__ 236/400 ____
# Affected correctors: 184.0
# Updated correctors: 25.0
# _____Sample__ 237/400 ____
# Affected correctors: 169.0
# Updated correctors: 26.0
# _____Sample__ 238/400 ____
# Affected correctors: 178.0
# Updated correctors: 26.0
# _____Sample__ 239/400 ____
# Affected correctors: 190.0
# Updated correctors: 26.0
# _____Sample__ 240/400 ____
# Affected correctors: 164.0
# Updated correctors: 25.0
# _____Sample__ 241/400 ____
# Affected correctors: 197.0
# Updated correctors: 26.0
# _____Sample__ 242/400 ____
# Affected correctors: 196.0
# Updated correctors: 26.0
# _____Sample__ 243/400 ____
# Affected correctors: 206.0
# Updated correctors: 26.0
# _____Sample__ 244/400 ____
# Affected correctors: 212.0
# Updated correctors: 25.0
# _____Sample__ 245/400 ____
# Affected correctors: 216.0
# Updated correctors: 26.0
# _____Sample__ 246/400 ____
# Affected correctors: 206.0
# Updated correctors: 26.0
# _____Sample__ 247/400 ____
# Affected correctors: 70.0
# Updated correctors: 26.0
# _____Sample__ 248/400 ____
# Affected correctors: 179.0
# Updated correctors: 26.0
# _____Sample__ 249/400 ____
# Affected correctors: 240.0
# Updated correctors: 26.0
# _____Sample__ 250/400 ____
# Affected correctors: 225.0
# Updated correctors: 26.0
# _____Sample__ 251/400 ____
# Affected correctors: 124.0
# Updated correctors: 25.0
# _____Sample__ 252/400 ____
# Affected correctors: 202.0
# Updated correctors: 25.0
# _____Sample__ 253/400 ____
# Affected correctors: 128.0
# Updated correctors: 26.0
# _____Sample__ 254/400 ____
# Affected correctors: 213.0
# Updated correctors: 25.0
# _____Sample__ 255/400 ____
# Affected correctors: 98.0
# Updated correctors: 26.0
# _____Sample__ 256/400 ____
# Affected correctors: 192.0
# Updated correctors: 25.0
# _____Sample__ 257/400 ____
# Affected correctors: 202.0
# Updated correctors: 25.0
# _____Sample__ 258/400 ____
# Affected correctors: 93.0
# Updated correctors: 25.0
# _____Sample__ 259/400 ____
# Affected correctors: 90.0
# Updated correctors: 26.0
# _____Sample__ 260/400 ____
# Affected correctors: 189.0
# Updated correctors: 26.0
# _____Sample__ 261/400 ____
# Affected correctors: 217.0
# Updated correctors: 26.0
# _____Sample__ 262/400 ____
# Affected correctors: 201.0
# Updated correctors: 25.0
# _____Sample__ 263/400 ____
# Affected correctors: 175.0
# Updated correctors: 26.0
# _____Sample__ 264/400 ____
# Affected correctors: 166.0
# Updated correctors: 26.0
# _____Sample__ 265/400 ____
# Affected correctors: 180.0
# Updated correctors: 26.0
# _____Sample__ 266/400 ____
# Affected correctors: 243.0
# Updated correctors: 25.0
# _____Sample__ 267/400 ____
# Affected correctors: 109.0
# Updated correctors: 26.0
# _____Sample__ 268/400 ____
# Affected correctors: 163.0
# Updated correctors: 25.0
# _____Sample__ 269/400 ____
# Affected correctors: 176.0
# Updated correctors: 26.0
# _____Sample__ 270/400 ____
# Affected correctors: 161.0
# Updated correctors: 25.0
# _____Sample__ 271/400 ____
# Affected correctors: 148.0
# Updated correctors: 26.0
# _____Sample__ 272/400 ____
# Affected correctors: 124.0
# Updated correctors: 25.0
# _____Sample__ 273/400 ____
# Affected correctors: 136.0
# Updated correctors: 26.0
# _____Sample__ 274/400 ____
# Affected correctors: 192.0
# Updated correctors: 25.0
# _____Sample__ 275/400 ____
# Affected correctors: 214.0
# Updated correctors: 25.0
# _____Sample__ 276/400 ____
# Affected correctors: 136.0
# Updated correctors: 26.0
# _____Sample__ 277/400 ____
# Affected correctors: 228.0
# Updated correctors: 26.0
# _____Sample__ 278/400 ____
# Affected correctors: 208.0
# Updated correctors: 26.0
# _____Sample__ 279/400 ____
# Affected correctors: 184.0
# Updated correctors: 25.0
# _____Sample__ 280/400 ____
# Affected correctors: 174.0
# Updated correctors: 25.0
# _____Sample__ 281/400 ____
# Affected correctors: 141.0
# Updated correctors: 25.0
# _____Sample__ 282/400 ____
# Affected correctors: 201.0
# Updated correctors: 25.0
# _____Sample__ 283/400 ____
# Affected correctors: 171.0
# Updated correctors: 25.0
# _____Sample__ 284/400 ____
# Affected correctors: 188.0
# Updated correctors: 26.0
# _____Sample__ 285/400 ____
# Affected correctors: 220.0
# Updated correctors: 26.0
# _____Sample__ 286/400 ____
# Affected correctors: 193.0
# Updated correctors: 25.0
# _____Sample__ 287/400 ____
# Affected correctors: 217.0
# Updated correctors: 26.0
# _____Sample__ 288/400 ____
# Affected correctors: 234.0
# Updated correctors: 25.0
# _____Sample__ 289/400 ____
# Affected correctors: 186.0
# Updated correctors: 26.0
# _____Sample__ 290/400 ____
# Affected correctors: 186.0
# Updated correctors: 26.0
# _____Sample__ 291/400 ____
# Affected correctors: 90.0
# Updated correctors: 26.0
# _____Sample__ 292/400 ____
# Affected correctors: 129.0
# Updated correctors: 26.0
# _____Sample__ 293/400 ____
# Affected correctors: 134.0
# Updated correctors: 25.0
# _____Sample__ 294/400 ____
# Affected correctors: 184.0
# Updated correctors: 25.0
# _____Sample__ 295/400 ____
# Affected correctors: 201.0
# Updated correctors: 25.0
# _____Sample__ 296/400 ____
# Affected correctors: 228.0
# Updated correctors: 26.0
# _____Sample__ 297/400 ____
# Affected correctors: 193.0
# Updated correctors: 25.0
# _____Sample__ 298/400 ____
# Affected correctors: 192.0
# Updated correctors: 25.0
# _____Sample__ 299/400 ____
# Affected correctors: 152.0
# Updated correctors: 25.0
# _____Sample__ 300/400 ____
# Affected correctors: 174.0
# Updated correctors: 25.0
# _____Sample__ 301/400 ____
# Affected correctors: 0.0
# nothing to update
# _____Sample__ 302/400 ____
# Affected correctors: 214.0
# Updated correctors: 25.0
# _____Sample__ 303/400 ____
# Affected correctors: 194.0
# Updated correctors: 25.0
# _____Sample__ 304/400 ____
# Affected correctors: 72.0
# Updated correctors: 25.0
# _____Sample__ 305/400 ____
# Affected correctors: 129.0
# Updated correctors: 26.0
# _____Sample__ 306/400 ____
# Affected correctors: 180.0
# Updated correctors: 26.0
# _____Sample__ 307/400 ____
# Affected correctors: 239.0
# Updated correctors: 26.0
# _____Sample__ 308/400 ____
# Affected correctors: 172.0
# Updated correctors: 25.0
# _____Sample__ 309/400 ____
# Affected correctors: 214.0
# Updated correctors: 25.0
# _____Sample__ 310/400 ____
# Affected correctors: 216.0
# Updated correctors: 26.0
# _____Sample__ 311/400 ____
# Affected correctors: 103.0
# Updated correctors: 25.0
# _____Sample__ 312/400 ____
# Affected correctors: 188.0
# Updated correctors: 26.0
# _____Sample__ 313/400 ____
# Affected correctors: 213.0
# Updated correctors: 25.0
# _____Sample__ 314/400 ____
# Affected correctors: 224.0
# Updated correctors: 25.0
# _____Sample__ 315/400 ____
# Affected correctors: 184.0
# Updated correctors: 25.0
# _____Sample__ 316/400 ____
# Affected correctors: 221.0
# Updated correctors: 25.0
# _____Sample__ 317/400 ____
# Affected correctors: 213.0
# Updated correctors: 25.0
# _____Sample__ 318/400 ____
# Affected correctors: 224.0
# Updated correctors: 25.0
# _____Sample__ 319/400 ____
# Affected correctors: 188.0
# Updated correctors: 26.0
# _____Sample__ 320/400 ____
# Affected correctors: 220.0
# Updated correctors: 26.0
# _____Sample__ 321/400 ____
# Affected correctors: 219.0
# Updated correctors: 26.0
# _____Sample__ 322/400 ____
# Affected correctors: 81.0
# Updated correctors: 25.0
# _____Sample__ 323/400 ____
# Affected correctors: 172.0
# Updated correctors: 25.0
# _____Sample__ 324/400 ____
# Affected correctors: 170.0
# Updated correctors: 26.0
# _____Sample__ 325/400 ____
# Affected correctors: 166.0
# Updated correctors: 26.0
# _____Sample__ 326/400 ____
# Affected correctors: 165.0
# Updated correctors: 26.0
# _____Sample__ 327/400 ____
# Affected correctors: 143.0
# Updated correctors: 25.0
# _____Sample__ 328/400 ____
# Affected correctors: 226.0
# Updated correctors: 26.0
# _____Sample__ 329/400 ____
# Affected correctors: 170.0
# Updated correctors: 26.0
# _____Sample__ 330/400 ____
# Affected correctors: 211.0
# Updated correctors: 25.0
# _____Sample__ 331/400 ____
# Affected correctors: 199.0
# Updated correctors: 26.0
# _____Sample__ 332/400 ____
# Affected correctors: 214.0
# Updated correctors: 25.0
# _____Sample__ 333/400 ____
# Affected correctors: 256.0
# Updated correctors: 26.0
# _____Sample__ 334/400 ____
# Affected correctors: 208.0
# Updated correctors: 26.0
# _____Sample__ 335/400 ____
# Affected correctors: 195.0
# Updated correctors: 26.0
# _____Sample__ 336/400 ____
# Affected correctors: 234.0
# Updated correctors: 25.0
# _____Sample__ 337/400 ____
# Affected correctors: 222.0
# Updated correctors: 25.0
# _____Sample__ 338/400 ____
# Affected correctors: 189.0
# Updated correctors: 26.0
# _____Sample__ 339/400 ____
# Affected correctors: 205.0
# Updated correctors: 26.0
# _____Sample__ 340/400 ____
# Affected correctors: 181.0
# Updated correctors: 25.0
# _____Sample__ 341/400 ____
# Affected correctors: 216.0
# Updated correctors: 26.0
# _____Sample__ 342/400 ____
# Affected correctors: 173.0
# Updated correctors: 25.0
# _____Sample__ 343/400 ____
# Affected correctors: 165.0
# Updated correctors: 26.0
# _____Sample__ 344/400 ____
# Affected correctors: 193.0
# Updated correctors: 25.0
# _____Sample__ 345/400 ____
# Affected correctors: 206.0
# Updated correctors: 26.0
# _____Sample__ 346/400 ____
# Affected correctors: 131.0
# Updated correctors: 25.0
# _____Sample__ 347/400 ____
# Affected correctors: 60.0
# Updated correctors: 26.0
# _____Sample__ 348/400 ____
# Affected correctors: 218.0
# Updated correctors: 26.0
# _____Sample__ 349/400 ____
# Affected correctors: 195.0
# Updated correctors: 26.0
# _____Sample__ 350/400 ____
# Affected correctors: 192.0
# Updated correctors: 25.0
# _____Sample__ 351/400 ____
# Affected correctors: 190.0
# Updated correctors: 26.0
# _____Sample__ 352/400 ____
# Affected correctors: 168.0
# Updated correctors: 26.0
# _____Sample__ 353/400 ____
# Affected correctors: 160.0
# Updated correctors: 26.0
# _____Sample__ 354/400 ____
# Affected correctors: 198.0
# Updated correctors: 26.0
# _____Sample__ 355/400 ____
# Affected correctors: 161.0
# Updated correctors: 25.0
# _____Sample__ 356/400 ____
# Affected correctors: 155.0
# Updated correctors: 26.0
# _____Sample__ 357/400 ____
# Affected correctors: 211.0
# Updated correctors: 25.0
# _____Sample__ 358/400 ____
# Affected correctors: 221.0
# Updated correctors: 25.0
# _____Sample__ 359/400 ____
# Affected correctors: 164.0
# Updated correctors: 25.0
# _____Sample__ 360/400 ____
# Affected correctors: 161.0
# Updated correctors: 25.0
# _____Sample__ 361/400 ____
# Affected correctors: 248.0
# Updated correctors: 26.0
# _____Sample__ 362/400 ____
# Affected correctors: 203.0
# Updated correctors: 25.0
# _____Sample__ 363/400 ____
# Affected correctors: 208.0
# Updated correctors: 26.0
# _____Sample__ 364/400 ____
# Affected correctors: 170.0
# Updated correctors: 26.0
# _____Sample__ 365/400 ____
# Affected correctors: 148.0
# Updated correctors: 26.0
# _____Sample__ 366/400 ____
# Affected correctors: 175.0
# Updated correctors: 26.0
# _____Sample__ 367/400 ____
# Affected correctors: 194.0
# Updated correctors: 25.0
# _____Sample__ 368/400 ____
# Affected correctors: 78.0
# Updated correctors: 26.0
# _____Sample__ 369/400 ____
# Affected correctors: 202.0
# Updated correctors: 25.0
# _____Sample__ 370/400 ____
# Affected correctors: 70.0
# Updated correctors: 26.0
# _____Sample__ 371/400 ____
# Affected correctors: 194.0
# Updated correctors: 25.0
# _____Sample__ 372/400 ____
# Affected correctors: 214.0
# Updated correctors: 25.0
# _____Sample__ 373/400 ____
# Affected correctors: 90.0
# Updated correctors: 26.0
# _____Sample__ 374/400 ____
# Affected correctors: 161.0
# Updated correctors: 25.0
# _____Sample__ 375/400 ____
# Affected correctors: 209.0
# Updated correctors: 26.0
# _____Sample__ 376/400 ____
# Affected correctors: 256.0
# Updated correctors: 26.0
# _____Sample__ 377/400 ____
# Affected correctors: 94.0
# Updated correctors: 25.0
# _____Sample__ 378/400 ____
# Affected correctors: 171.0
# Updated correctors: 25.0
# _____Sample__ 379/400 ____
# Affected correctors: 231.0
# Updated correctors: 25.0
# _____Sample__ 380/400 ____
# Affected correctors: 216.0
# Updated correctors: 26.0
# _____Sample__ 381/400 ____
# Affected correctors: 199.0
# Updated correctors: 26.0
# _____Sample__ 382/400 ____
# Affected correctors: 207.0
# Updated correctors: 26.0
# _____Sample__ 383/400 ____
# Affected correctors: 197.0
# Updated correctors: 26.0
# _____Sample__ 384/400 ____
# Affected correctors: 100.0
# Updated correctors: 26.0
# _____Sample__ 385/400 ____
# Affected correctors: 125.0
# Updated correctors: 27.0
# _____Sample__ 386/400 ____
# Affected correctors: 211.0
# Updated correctors: 25.0
# _____Sample__ 387/400 ____
# Affected correctors: 176.0
# Updated correctors: 26.0
# _____Sample__ 388/400 ____
# Affected correctors: 207.0
# Updated correctors: 26.0
# _____Sample__ 389/400 ____
# Affected correctors: 201.0
# Updated correctors: 25.0
# _____Sample__ 390/400 ____
# Affected correctors: 117.0
# Updated correctors: 26.0
# _____Sample__ 391/400 ____
# Affected correctors: 168.0
# Updated correctors: 26.0
# _____Sample__ 392/400 ____
# Affected correctors: 90.0
# Updated correctors: 26.0
# _____Sample__ 393/400 ____
# Affected correctors: 138.0
# Updated correctors: 26.0
# _____Sample__ 394/400 ____
# Affected correctors: 105.0
# Updated correctors: 27.0
# _____Sample__ 395/400 ____
# Affected correctors: 119.0
# Updated correctors: 26.0
# _____Sample__ 396/400 ____
# Affected correctors: 241.0
# Updated correctors: 25.0
# _____Sample__ 397/400 ____
# Affected correctors: 240.0
# Updated correctors: 26.0
# _____Sample__ 398/400 ____
# Affected correctors: 238.0
# Updated correctors: 26.0
# _____Sample__ 399/400 ____
# Affected correctors: 210.0
# Updated correctors: 26.0
# _____Sample__ 400/400 ____
# Affected correctors: 146.0
# Updated correctors: 26.0
# p = 20%
# uLod  0.00652520876172 +- 4.54596214482e-06
# uVcLod 0.00651456531382 +- 1.04479697591e-05
# uLodVcLod 0.000262894724885 +- 2.18887348811e-05
# _____Sample__ 1/400 ____
# Affected correctors: 130.0
# Updated correctors: 51.0
# _____Sample__ 2/400 ____
# Affected correctors: 150.0
# Updated correctors: 51.0
# _____Sample__ 3/400 ____
# Affected correctors: 187.0
# Updated correctors: 51.0
# _____Sample__ 4/400 ____
# Affected correctors: 238.0
# Updated correctors: 52.0
# _____Sample__ 5/400 ____
# Affected correctors: 247.0
# Updated correctors: 51.0
# _____Sample__ 6/400 ____
# Affected correctors: 0.0
# nothing to update
# _____Sample__ 7/400 ____
# Affected correctors: 232.0
# Updated correctors: 51.0
# _____Sample__ 8/400 ____
# Affected correctors: 200.0
# Updated correctors: 51.0
# _____Sample__ 9/400 ____
# Affected correctors: 0.0
# nothing to update
# _____Sample__ 10/400 ____
# Affected correctors: 224.0
# Updated correctors: 51.0
# _____Sample__ 11/400 ____
# Affected correctors: 136.0
# Updated correctors: 51.0
# _____Sample__ 12/400 ____
# Affected correctors: 201.0
# Updated correctors: 51.0
# _____Sample__ 13/400 ____
# Affected correctors: 96.0
# Updated correctors: 51.0
# _____Sample__ 14/400 ____
# Affected correctors: 227.0
# Updated correctors: 51.0
# _____Sample__ 15/400 ____
# Affected correctors: 226.0
# Updated correctors: 51.0
# _____Sample__ 16/400 ____
# Affected correctors: 98.0
# Updated correctors: 52.0
# _____Sample__ 17/400 ____
# Affected correctors: 220.0
# Updated correctors: 51.0
# _____Sample__ 18/400 ____
# Affected correctors: 167.0
# Updated correctors: 51.0
# _____Sample__ 19/400 ____
# Affected correctors: 161.0
# Updated correctors: 51.0
# _____Sample__ 20/400 ____
# Affected correctors: 243.0
# Updated correctors: 52.0
# _____Sample__ 21/400 ____
# Affected correctors: 191.0
# Updated correctors: 51.0
# _____Sample__ 22/400 ____
# Affected correctors: 151.0
# Updated correctors: 51.0
# _____Sample__ 23/400 ____
# Affected correctors: 193.0
# Updated correctors: 52.0
# _____Sample__ 24/400 ____
# Affected correctors: 158.0
# Updated correctors: 52.0
# _____Sample__ 25/400 ____
# Affected correctors: 201.0
# Updated correctors: 51.0
# _____Sample__ 26/400 ____
# Affected correctors: 151.0
# Updated correctors: 51.0
# _____Sample__ 27/400 ____
# Affected correctors: 222.0
# Updated correctors: 51.0
# _____Sample__ 28/400 ____
# Affected correctors: 241.0
# Updated correctors: 51.0
# _____Sample__ 29/400 ____
# Affected correctors: 132.0
# Updated correctors: 50.0
# _____Sample__ 30/400 ____
# Affected correctors: 232.0
# Updated correctors: 51.0
# _____Sample__ 31/400 ____
# Affected correctors: 189.0
# Updated correctors: 51.0
# _____Sample__ 32/400 ____
# Affected correctors: 185.0
# Updated correctors: 51.0
# _____Sample__ 33/400 ____
# Affected correctors: 165.0
# Updated correctors: 51.0
# _____Sample__ 34/400 ____
# Affected correctors: 132.0
# Updated correctors: 50.0
# _____Sample__ 35/400 ____
# Affected correctors: 212.0
# Updated correctors: 51.0
# _____Sample__ 36/400 ____
# Affected correctors: 202.0
# Updated correctors: 51.0
# _____Sample__ 37/400 ____
# Affected correctors: 227.0
# Updated correctors: 51.0
# _____Sample__ 38/400 ____
# Affected correctors: 177.0
# Updated correctors: 51.0
# _____Sample__ 39/400 ____
# Affected correctors: 112.0
# Updated correctors: 50.0
# _____Sample__ 40/400 ____
# Affected correctors: 234.0
# Updated correctors: 51.0
# _____Sample__ 41/400 ____
# Affected correctors: 95.0
# Updated correctors: 51.0
# _____Sample__ 42/400 ____
# Affected correctors: 256.0
# Updated correctors: 51.0
# _____Sample__ 43/400 ____
# Affected correctors: 175.0
# Updated correctors: 51.0
# _____Sample__ 44/400 ____
# Affected correctors: 138.0
# Updated correctors: 52.0
# _____Sample__ 45/400 ____
# Affected correctors: 176.0
# Updated correctors: 51.0
# _____Sample__ 46/400 ____
# Affected correctors: 228.0
# Updated correctors: 52.0
# _____Sample__ 47/400 ____
# Affected correctors: 174.0
# Updated correctors: 51.0
# _____Sample__ 48/400 ____
# Affected correctors: 205.0
# Updated correctors: 51.0
# _____Sample__ 49/400 ____
# Affected correctors: 134.0
# Updated correctors: 52.0
# _____Sample__ 50/400 ____
# Affected correctors: 120.0
# Updated correctors: 51.0
# _____Sample__ 51/400 ____
# Affected correctors: 115.0
# Updated correctors: 51.0
# _____Sample__ 52/400 ____
# Affected correctors: 200.0
# Updated correctors: 51.0
# _____Sample__ 53/400 ____
# Affected correctors: 171.0
# Updated correctors: 51.0
# _____Sample__ 54/400 ____
# Affected correctors: 201.0
# Updated correctors: 51.0
# _____Sample__ 55/400 ____
# Affected correctors: 168.0
# Updated correctors: 52.0
# _____Sample__ 56/400 ____
# Affected correctors: 181.0
# Updated correctors: 51.0
# _____Sample__ 57/400 ____
# Affected correctors: 205.0
# Updated correctors: 51.0
# _____Sample__ 58/400 ____
# Affected correctors: 216.0
# Updated correctors: 51.0
# _____Sample__ 59/400 ____
# Affected correctors: 195.0
# Updated correctors: 51.0
# _____Sample__ 60/400 ____
# Affected correctors: 213.0
# Updated correctors: 52.0
# _____Sample__ 61/400 ____
# Affected correctors: 229.0
# Updated correctors: 51.0
# _____Sample__ 62/400 ____
# Affected correctors: 217.0
# Updated correctors: 51.0
# _____Sample__ 63/400 ____
# Affected correctors: 170.0
# Updated correctors: 51.0
# _____Sample__ 64/400 ____
# Affected correctors: 48.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-0614b65a3893> in <module>()
#      88
#      89 ROOT = '../test_data/MonteCarlo/Coef3/p40'
# ---> 90 a, mum = result(pglod, world, CoefClass, A, f, MC, numberofcorrectors, MCplot=True, ROOT=ROOT)
#      91
#      92 print 'p = '+ str(20) + '%'
#
# <ipython-input-3-4e93f494e18d> in result(pglod, world, CoefClass, A, f, MC, numberofcorrectors, MCplot, ROOT)
#      29     for i in range(0,MC):
#      30         print '_____Sample__ ' + str(i+1) + '/' + str(MC) + ' ____'
# ---> 31         xmLod, xmVcLod, xmLodVcLod = VcLod(pglod, world, CoefClass, f, prob=100, numberofcorrectors=numberofcorrectors, m=i)
#      32         xmLoda.append(xmLod)
#      33         xmVcLoda.append(xmVcLod)
#
# <ipython-input-5-59d3061eac88> in VcLod(pglod, world, CoefClass, f, prob, numberofcorrectors, m)
#      54
#      55     else:
# ---> 56         tol = tolrev[until]
#      57
#      58         vistol = pglod.updateCorrectors(Anew, tol, f, clearFineQuantities=False)
#
# IndexError: list index out of range

# %%
#correctors that we will update in %
numberofcorrectors = 20

ROOT = '../test_data/MonteCarlo/Coef3/p40'
a, mum = result(pglod, world, CoefClass, A, f, MC, numberofcorrectors, MCplot=True, ROOT=ROOT)

print 'p = '+ str(20) + '%'
print 'uLod  ' + str(mum[0]) + ' +- ' + str(a[0])
print 'uVcLod ' + str(mum[1]) + ' +- ' + str(a[1])
print 'uLodVcLod ' + str(mum[2]) + ' +- ' + str(a[2])
# Out:
# _____Sample__ 1/400 ____
# Affected correctors: 55.0
# Updated correctors: 51.0
# _____Sample__ 2/400 ____
# Affected correctors: 245.0
# Updated correctors: 51.0
# _____Sample__ 3/400 ____
# Affected correctors: 230.0
# Updated correctors: 51.0
# _____Sample__ 4/400 ____
# Affected correctors: 181.0
# Updated correctors: 51.0
# _____Sample__ 5/400 ____
# Affected correctors: 149.0
# Updated correctors: 52.0
# _____Sample__ 6/400 ____
